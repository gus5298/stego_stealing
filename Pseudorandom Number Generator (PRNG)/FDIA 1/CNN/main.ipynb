# %%
import os
import cv2
import numpy as np
import pandas as pd
import random
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib as mpl
import hashlib
import tensorflow as tf
from tensorflow.keras.models import load_model
from skimage.metrics import structural_similarity as ssim
from scipy.fftpack import dct
import math

mpl.rcParams['font.family'] = 'DejaVu Sans'

# %%
# === CONFIGURATION === #
IMG_SIZE = (128, 128)
NUM_PIXELS = 24
MESSAGE_BITS = NUM_PIXELS
CHANNELS = 1
CLASS_NAMES = ['Normal', 'Attack']
SEED_RESERVED_PIXELS = 300
SEED_SECRET_KEY = "my_shared_passphrase"

# %%
# === MESSAGE UTILS === #
def generate_random_message(chars=3):
    return ''.join(random.choices(string.ascii_letters, k=chars))

def string_to_bits(s):
    return [int(b) for c in s.encode('ascii') for b in format(c, '08b')][:MESSAGE_BITS]

def bits_to_string(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        if len(byte) == 8:
            chars.append(chr(int(''.join(map(str, byte)), 2)))
    return ''.join(chars)

def clean_excel_string(s):
    return ''.join(c for c in s if c.isalpha())

# %%
# === PRNG SEED-HIDING BASED ON IMAGE CONTENT + SHARED KEY === #
def get_seed_hiding_key(secret_key: str, image: np.ndarray):
    image_hash = hashlib.sha256(image.tobytes()).hexdigest()
    combined = secret_key + image_hash
    digest = hashlib.sha256(combined.encode()).hexdigest()
    return int(digest, 16) % (2**32)

# %%
# === EMBEDDING === #
def embed_lsb(image, bits, coords):
    flat = image.flatten()
    for i, (y, x) in enumerate(coords):
        if not (0 <= y < image.shape[0] and 0 <= x < image.shape[1]):
            continue
        idx = y * image.shape[1] + x
        if idx < SEED_RESERVED_PIXELS:
            continue
        flat[idx] = (flat[idx] & ~1) | bits[i]
    return flat.reshape(image.shape)

# %%
# === SEED COORDINATES & EMBEDDING === #
def get_seed_embedding_coords(image, total_reserved=SEED_RESERVED_PIXELS, bits=32, seed_secret_key=SEED_SECRET_KEY):
    seed_key = get_seed_hiding_key(seed_secret_key, image)
    np.random.seed(seed_key)
    coords = np.random.choice(range(total_reserved), size=bits, replace=False)
    return coords

def embed_seed_value(image, seed_bits, seed_secret_key, coords=None):
    if coords is None:
        coords = get_seed_embedding_coords(image.copy(), seed_secret_key=seed_secret_key)
    flat = image.flatten()
    for i, idx in enumerate(coords):
        flat[idx] = (flat[idx] & ~1) | seed_bits[i]
    return flat.reshape(image.shape), coords

def extract_seed_value(image, seed_secret_key, coords=None):
    if coords is None:
        coords = get_seed_embedding_coords(image.copy(), seed_secret_key=seed_secret_key)
    flat = image.flatten()
    seed_bits = [flat[idx] & 1 for idx in coords]
    seed_value = int(''.join(map(str, seed_bits)), 2)
    return seed_value

# %%
# === SEED GENERATION === #
def get_seed_from_image(secret_key: str, image: np.ndarray):
    image_hash = hashlib.sha256(image.tobytes()).hexdigest()
    combined = secret_key + image_hash + "_main_seed"
    digest = hashlib.sha256(combined.encode()).hexdigest()
    return int(digest, 16) % (2**32)

def generate_prng_pixel_positions(image_shape, count, seed_value):
    np.random.seed(seed_value)
    h, w = image_shape
    total_pixels = h * w
    excluded_pixels = set(range(SEED_RESERVED_PIXELS))
    valid_indices = list(set(range(total_pixels)) - excluded_pixels)
    indices = np.random.choice(valid_indices, size=count, replace=False)
    ys, xs = np.unravel_index(indices, (h, w))
    return list(zip(ys, xs))

# %%
# === CNN FEATURE EXTRACTION === #
def extract_features(image):
    image = image.astype(np.float32) / 255.0
    image = np.expand_dims(image, axis=-1)
    image = np.expand_dims(image, axis=0)
    return image

def analyze_with_cnn(image, model):
    cnn_input = extract_features(image)
    prob = float(model.predict(cnn_input, verbose=0)[0])
    predicted_class = CLASS_NAMES[int(prob >= 0.5)]
    confidence = prob if predicted_class == "Attack" else 1 - prob
    return predicted_class, confidence

# %%
# === DECODING & QUALITY METRICS === #
def decode_message(image, coords):
    flat = image.flatten()
    msg_bits = [flat[y * image.shape[1] + x] & 1 for y, x in coords[:NUM_PIXELS]]
    return bits_to_string(msg_bits)

def calculate_mse(original, stego):
    return np.mean((original.astype(np.float32) - stego.astype(np.float32)) ** 2)

def calculate_psnr(mse, max_pixel=255.0):
    if mse == 0:
        return float('inf')
    return 20 * math.log10(max_pixel / math.sqrt(mse))

def calculate_ssim(original, stego):
    return ssim(original, stego)

def compute_dct_difference(original, stego):
    original_dct = dct(dct(original.T, norm='ortho').T, norm='ortho')
    stego_dct = dct(dct(stego.T, norm='ortho').T, norm='ortho')
    diff = np.abs(original_dct - stego_dct)
    return np.mean(diff), np.max(diff)

# %%
# === MAIN FUNCTION === #
def process_folder(input_folder, model_path, stego_output_folder, results_output_folder, seed_secret_key):
    model = load_model(model_path)
    results = []

    if not os.path.exists(stego_output_folder):
        os.makedirs(stego_output_folder)

    image_files = [f for f in os.listdir(input_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    for filename in image_files:
        print(f"Processing: {filename}")
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image, IMG_SIZE)
        image = image.astype(np.uint8)

        # 🔍 Prediction on original image
        orig_pred_class, orig_confidence = analyze_with_cnn(image, model)

        seed_value = get_seed_from_image(seed_secret_key, image)
        seed_bits = [int(b) for b in format(seed_value, '032b')]

        stego_img, seed_coords = embed_seed_value(image.copy(), seed_bits, seed_secret_key)
        extracted_seed = extract_seed_value(stego_img, seed_secret_key, coords=seed_coords)
        key_match_status = "Matched" if extracted_seed == seed_value else "Mismatched"

        prng_pixels = generate_prng_pixel_positions(image.shape, NUM_PIXELS, seed_value)
        original_msg = generate_random_message(chars=3)
        msg_bits = string_to_bits(original_msg)
        final_stego = embed_lsb(stego_img.copy(), msg_bits, prng_pixels)

        decoded_msg = decode_message(final_stego, prng_pixels)
        msg_match_status = "Matched" if clean_excel_string(decoded_msg) == clean_excel_string(original_msg) else "Mismatched"

        # 🔍 Prediction on stego image
        pred_class, confidence = analyze_with_cnn(final_stego, model)

        stego_image_filename = f"stego_{filename}"
        stego_image_path = os.path.join(stego_output_folder, stego_image_filename)
        cv2.imwrite(stego_image_path, final_stego)

        mse_value = calculate_mse(image, final_stego)
        psnr_value = calculate_psnr(mse_value)
        ssim_value = calculate_ssim(image, final_stego)
        mean_dct_diff, max_dct_diff = compute_dct_difference(image, final_stego)

        results.append({
            "Image": filename,
            "Original Message": original_msg,
            "Decoded Message": decoded_msg,
            "Message Match": msg_match_status,
            "Seed": seed_value,
            "Extracted Seed": extracted_seed,
            "Key Match": key_match_status,
            "Original CNN Predicted Class": orig_pred_class,
            "Original Confidence": orig_confidence,
            "CNN Predicted Class": pred_class,
            "Confidence": confidence,
            "Stego Image Path": stego_image_path,
            "MSE": round(mse_value, 4),
            "PSNR": round(psnr_value, 2),
            "SSIM": round(ssim_value, 4),
            "Mean DCT Diff": round(mean_dct_diff, 4),
            "Max DCT Diff": round(max_dct_diff, 4)
        })

    df = pd.DataFrame(results)

    avg_metrics = {
        "Image": "AVERAGE",
        "MSE": df["MSE"].mean(),
        "PSNR": df["PSNR"].mean(),
        "SSIM": df["SSIM"].mean(),
        "Mean DCT Diff": df["Mean DCT Diff"].mean(),
        "Max DCT Diff": df["Max DCT Diff"].mean()
    }

    # ✅ Automatically get label from input folder
    true_label = os.path.basename(input_folder).strip()
    df["True Label"] = true_label

    df_filtered = df[df["Image"] != "AVERAGE"]

    # Confusion matrix for stego images
    cm_stego = confusion_matrix(df_filtered["True Label"], df_filtered["CNN Predicted Class"], labels=CLASS_NAMES)
    # Confusion matrix for original images
    cm_original = confusion_matrix(df_filtered["True Label"], df_filtered["Original CNN Predicted Class"], labels=CLASS_NAMES)

    # === Save Excel Results === #
    output_excel = os.path.join(results_output_folder, "stego_analysis_results_with_metrics.xlsx")
    with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:
        df_filtered.to_excel(writer, index=False, sheet_name="Per Image Results")
        pd.DataFrame([avg_metrics]).to_excel(writer, index=False, sheet_name="Summary Averages")

    # === Save Confusion Matrices === #
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_stego, annot=True, fmt='d', cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix for Stego Images")
    plt.tight_layout()
    plt.savefig(os.path.join(results_output_folder, "stego_confusion_matrix.png"))
    plt.close()

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_original, annot=True, fmt='d', cmap="Greens", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix for Original Images")
    plt.tight_layout()
    plt.savefig(os.path.join(results_output_folder, "original_confusion_matrix.png"))
    plt.close()

    # === Save Match Count Plots === #
    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x="Key Match")
    plt.title("Seed Match Count (Initial PRNG)")
    plt.ylabel("Number of Images")
    plt.xlabel("Key Match Status")
    plt.tight_layout()
    plt.savefig(os.path.join(results_output_folder, "initial_prng_key_match_count.png"))
    plt.close()

    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x="Message Match")
    plt.title("Message Match Count (Second PRNG)")
    plt.ylabel("Number of Images")
    plt.xlabel("Message Match Status")
    plt.tight_layout()
    plt.savefig(os.path.join(results_output_folder, "second_prng_message_match_count.png"))
    plt.close()

    print(f"\u2705 All results saved to: {results_output_folder}")

# %%
# === RUN === #
input_folder = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\FDIA 1\CNN\Images FDIA 1\Normal"
model_path = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\FDIA 1\CNN\cnn_2_class_model_grayscale.h5"
stego_output_folder = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\FDIA 1\CNN\stego_images"
results_output_folder = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\FDIA 1\CNN\stego_images"
seed_secret_key = "Gustavo_Sanchez"

process_folder(input_folder, model_path, stego_output_folder, results_output_folder, seed_secret_key)
# Out:
# Processing: image_00001.png
# Processing: image_00002.png
# Processing: image_00003.png
# Processing: image_00004.png
# Processing: image_00005.png
# Processing: image_00006.png
# Processing: image_00007.png
# Processing: image_00008.png
# Processing: image_00009.png
# Processing: image_00010.png
# Processing: image_00011.png
# Processing: image_00012.png
# Processing: image_00013.png
# Processing: image_00014.png
# Processing: image_00015.png
# Processing: image_00016.png
# Processing: image_00017.png
# Processing: image_00018.png
# Processing: image_00019.png
# Processing: image_00020.png
# Processing: image_00021.png
# Processing: image_00022.png
# Processing: image_00023.png
# Processing: image_00024.png
# Processing: image_00025.png
# Processing: image_00026.png
# Processing: image_00027.png
# Processing: image_00028.png
# Processing: image_00029.png
# Processing: image_00030.png
# Processing: image_00031.png
# Processing: image_00032.png
# Processing: image_00033.png
# Processing: image_00034.png
# Processing: image_00035.png
# Processing: image_00036.png
# Processing: image_00037.png
# Processing: image_00038.png
# Processing: image_00039.png
# Processing: image_00040.png
# Processing: image_00041.png
# Processing: image_00042.png
# Processing: image_00043.png
# Processing: image_00044.png
# Processing: image_00045.png
# Processing: image_00046.png
# Processing: image_00047.png
# Processing: image_00048.png
# Processing: image_00049.png
# Processing: image_00050.png
# Processing: image_00051.png
# Processing: image_00052.png
# Processing: image_00053.png
# Processing: image_00054.png
# Processing: image_00055.png
# Processing: image_00056.png
# Processing: image_00057.png
# Processing: image_00058.png
# Processing: image_00059.png
# Processing: image_00060.png
# Processing: image_00061.png
# Processing: image_00062.png
# Processing: image_00063.png
# Processing: image_00064.png
# Processing: image_00065.png
# Processing: image_00066.png
# Processing: image_00067.png
# Processing: image_00068.png
# Processing: image_00069.png
# Processing: image_00070.png
# Processing: image_00071.png
# Processing: image_00072.png
# Processing: image_00073.png
# Processing: image_00074.png
# Processing: image_00075.png
# Processing: image_00076.png
# Processing: image_00077.png
# Processing: image_00078.png
# Processing: image_00079.png
# Processing: image_00080.png
# Processing: image_00081.png
# Processing: image_00082.png
# Processing: image_00083.png
# Processing: image_00084.png
# Processing: image_00085.png
# Processing: image_00086.png
# Processing: image_00087.png
# Processing: image_00088.png
# Processing: image_00089.png
# Processing: image_00090.png
# Processing: image_00091.png
# Processing: image_00092.png
# Processing: image_00093.png
# Processing: image_00094.png
# Processing: image_00095.png
# Processing: image_00096.png
# Processing: image_00097.png
# Processing: image_00098.png
# Processing: image_01000.png
# Processing: image_01001.png
# Processing: image_01002.png
# Processing: image_01003.png
# Processing: image_01004.png
# Processing: image_01005.png
# Processing: image_01006.png
# Processing: image_01007.png
# Processing: image_01008.png
# Processing: image_01009.png
# Processing: image_01010.png
# Processing: image_01011.png
# Processing: image_01012.png
# Processing: image_01013.png
# Processing: image_01014.png
# Processing: image_01015.png
# Processing: image_01016.png
# Processing: image_01017.png
# Processing: image_01018.png
# Processing: image_01019.png
# Processing: image_01020.png
# Processing: image_01021.png
# Processing: image_01022.png
# Processing: image_01023.png
# Processing: image_01024.png
# Processing: image_01025.png
# Processing: image_01026.png
# Processing: image_01027.png
# Processing: image_01028.png
# Processing: image_01029.png
# Processing: image_01030.png
# Processing: image_01031.png
# Processing: image_01032.png
# Processing: image_01033.png
# Processing: image_01034.png
# Processing: image_01035.png
# Processing: image_01036.png
# Processing: image_01037.png
# Processing: image_01038.png
# Processing: image_01039.png
# Processing: image_01040.png
# Processing: image_01041.png
# Processing: image_01042.png
# Processing: image_01043.png
# Processing: image_01044.png
# Processing: image_01045.png
# Processing: image_01046.png
# Processing: image_01047.png
# Processing: image_01048.png
# Processing: image_01049.png
# Processing: image_01050.png
# Processing: image_01051.png
# Processing: image_01052.png
# Processing: image_01053.png
# Processing: image_01054.png
# Processing: image_01055.png
# Processing: image_01056.png
# Processing: image_01057.png
# Processing: image_01058.png
# Processing: image_01059.png
# Processing: image_01060.png
# Processing: image_01061.png
# Processing: image_01062.png
# Processing: image_01063.png
# Processing: image_01064.png
# Processing: image_01065.png
# Processing: image_01066.png
# Processing: image_01067.png
# Processing: image_01068.png
# Processing: image_01069.png
# Processing: image_01070.png
# Processing: image_01071.png
# Processing: image_01072.png
# Processing: image_01073.png
# Processing: image_01074.png
# Processing: image_01075.png
# Processing: image_01076.png
# Processing: image_01077.png
# Processing: image_01078.png
# Processing: image_01079.png
# Processing: image_01080.png
# Processing: image_01081.png
# Processing: image_01082.png
# Processing: image_01083.png
# Processing: image_01084.png
# Processing: image_01085.png
# Processing: image_01086.png
# Processing: image_01087.png
# Processing: image_01088.png
# Processing: image_01089.png
# Processing: image_01090.png
# Processing: image_01091.png
# Processing: image_01092.png
# Processing: image_01093.png
# Processing: image_01094.png
# Processing: image_01095.png
# Processing: image_01096.png
# Processing: image_01097.png
# Processing: image_01098.png
# Processing: image_01099.png
# Processing: image_01100.png
# Processing: image_01101.png
# Processing: image_01102.png
# Processing: image_01103.png
# Processing: image_01104.png
# Processing: image_01105.png
# Processing: image_01106.png
# Processing: image_01107.png
# Processing: image_01108.png
# Processing: image_01109.png
# Processing: image_01110.png
# Processing: image_01111.png
# Processing: image_01112.png
# Processing: image_01113.png
# Processing: image_01114.png
# Processing: image_01115.png
# Processing: image_01116.png
# Processing: image_01117.png
# Processing: image_01118.png
# Processing: image_01119.png
# Processing: image_01120.png
# Processing: image_01121.png
# Processing: image_01122.png
# Processing: image_01123.png
# Processing: image_01124.png
# Processing: image_01125.png
# Processing: image_01126.png
# Processing: image_01127.png
# Processing: image_01128.png
# Processing: image_01129.png
# Processing: image_01130.png
# Processing: image_01131.png
# Processing: image_01132.png
# Processing: image_01133.png
# Processing: image_01134.png
# Processing: image_01135.png
# Processing: image_01136.png
# Processing: image_01137.png
# Processing: image_01138.png
# Processing: image_01139.png
# Processing: image_01140.png
# Processing: image_01141.png
# Processing: image_01142.png
# Processing: image_01143.png
# Processing: image_01144.png
# Processing: image_01145.png
# Processing: image_01146.png
# Processing: image_01147.png
# Processing: image_01148.png
# Processing: image_01149.png
# Processing: image_01150.png
# Processing: image_01151.png
# Processing: image_01152.png
# Processing: image_01153.png
# Processing: image_01154.png
# Processing: image_01155.png
# Processing: image_01156.png
# Processing: image_01157.png
# Processing: image_01158.png
# Processing: image_01159.png
# Processing: image_01160.png
# Processing: image_01161.png
# Processing: image_01162.png
# Processing: image_01163.png
# Processing: image_01164.png
# Processing: image_01165.png
# Processing: image_01166.png
# Processing: image_01167.png
# Processing: image_01168.png
# Processing: image_01169.png
# Processing: image_01170.png
# Processing: image_01171.png
# Processing: image_01172.png
# Processing: image_01173.png
# Processing: image_01174.png
# Processing: image_01175.png
# Processing: image_01176.png
# Processing: image_01177.png
# Processing: image_01178.png
# Processing: image_01179.png
# Processing: image_01180.png
# Processing: image_01181.png
# Processing: image_01182.png
# Processing: image_01183.png
# Processing: image_01184.png
# Processing: image_01185.png
# Processing: image_01186.png
# Processing: image_01187.png
# Processing: image_01188.png
# Processing: image_01189.png
# Processing: image_01190.png
# Processing: image_01191.png
# Processing: image_01192.png
# Processing: image_01193.png
# Processing: image_01194.png
# Processing: image_01195.png
# Processing: image_01196.png
# Processing: image_01197.png
# Processing: image_01198.png
# Processing: image_01199.png
# Processing: image_01200.png
# Processing: image_01201.png
# Processing: image_01202.png
# Processing: image_01203.png
# Processing: image_01204.png
# Processing: image_01205.png
# Processing: image_01206.png
# Processing: image_01207.png
# Processing: image_01208.png
# Processing: image_01209.png
# Processing: image_01210.png
# Processing: image_01211.png
# Processing: image_01212.png
# Processing: image_01213.png
# Processing: image_01214.png
# Processing: image_01215.png
# Processing: image_01216.png
# Processing: image_01217.png
# Processing: image_01218.png
# Processing: image_01219.png
# Processing: image_01220.png
# Processing: image_01221.png
# Processing: image_01222.png
# Processing: image_01223.png
# Processing: image_01224.png
# Processing: image_01225.png
# Processing: image_01226.png
# Processing: image_01227.png
# Processing: image_01228.png
# Processing: image_01229.png
# Processing: image_01230.png
# Processing: image_01231.png
# Processing: image_01232.png
# Processing: image_01233.png
# Processing: image_01234.png
# Processing: image_01235.png
# Processing: image_01236.png
# Processing: image_01237.png
# Processing: image_01238.png
# Processing: image_01239.png
# Processing: image_01240.png
# Processing: image_01241.png
# Processing: image_01242.png
# Processing: image_01243.png
# Processing: image_01244.png
# Processing: image_01245.png
# Processing: image_01246.png
# Processing: image_01247.png
# Processing: image_01248.png
# Processing: image_01249.png
# Processing: image_01250.png
# Processing: image_01251.png
# Processing: image_01252.png
# Processing: image_01253.png
# Processing: image_01254.png
# Processing: image_01255.png
# Processing: image_01256.png
# Processing: image_01257.png
# Processing: image_01258.png
# Processing: image_01259.png
# Processing: image_01260.png
# Processing: image_01261.png
# Processing: image_01262.png
# Processing: image_01263.png
# Processing: image_01264.png
# Processing: image_01265.png
# Processing: image_01266.png
# Processing: image_01267.png
# Processing: image_01268.png
# Processing: image_01269.png
# Processing: image_01270.png
# Processing: image_01271.png
# Processing: image_01272.png
# Processing: image_01273.png
# Processing: image_01274.png
# Processing: image_01275.png
# Processing: image_01276.png
# Processing: image_01277.png
# Processing: image_01278.png
# Processing: image_01279.png
# Processing: image_01280.png
# Processing: image_01281.png
# Processing: image_01282.png
# Processing: image_01283.png
# Processing: image_01284.png
# Processing: image_01285.png
# Processing: image_01286.png
# Processing: image_01287.png
# Processing: image_01288.png
# Processing: image_01289.png
# Processing: image_01290.png
# Processing: image_01291.png
# Processing: image_01292.png
# Processing: image_01293.png
# Processing: image_01294.png
# Processing: image_01295.png
# Processing: image_01296.png
# Processing: image_01297.png
# Processing: image_01298.png
# Processing: image_01299.png
# Processing: image_01300.png
# Processing: image_01301.png
# Processing: image_01302.png
# Processing: image_01303.png
# Processing: image_01304.png
# Processing: image_01305.png
# Processing: image_01306.png
# Processing: image_01307.png
# Processing: image_01308.png
# Processing: image_01309.png
# Processing: image_01310.png
# Processing: image_01311.png
# Processing: image_01312.png
# Processing: image_01313.png
# Processing: image_01314.png
# Processing: image_01315.png
# Processing: image_01316.png
# Processing: image_01317.png
# Processing: image_01318.png
# Processing: image_01319.png
# Processing: image_01320.png
# Processing: image_01321.png
# Processing: image_01322.png
# Processing: image_01323.png
# Processing: image_01324.png
# Processing: image_01325.png
# Processing: image_01326.png
# Processing: image_01327.png
# Processing: image_01328.png
# Processing: image_01329.png
# Processing: image_01330.png
# Processing: image_01331.png
# Processing: image_01332.png
# Processing: image_01333.png
# Processing: image_01334.png
# Processing: image_01335.png
# Processing: image_01336.png
# Processing: image_01337.png
# Processing: image_01338.png
# Processing: image_01339.png
# Processing: image_01340.png
# Processing: image_01341.png
# Processing: image_01342.png
# Processing: image_01343.png
# Processing: image_01344.png
# Processing: image_01345.png
# Processing: image_01346.png
# Processing: image_01347.png
# Processing: image_01348.png
# Processing: image_01349.png
# Processing: image_01350.png
# Processing: image_01351.png
# Processing: image_01352.png
# Processing: image_01353.png
# Processing: image_01354.png
# Processing: image_01355.png
# Processing: image_01356.png
# Processing: image_01357.png
# Processing: image_01358.png
# Processing: image_01359.png
# Processing: image_01360.png
# Processing: image_01361.png
# Processing: image_01362.png
# Processing: image_01363.png
# Processing: image_01364.png
# Processing: image_01365.png
# Processing: image_01366.png
# Processing: image_01367.png
# Processing: image_01368.png
# Processing: image_01369.png
# Processing: image_01370.png
# Processing: image_01371.png
# Processing: image_01372.png
# Processing: image_01373.png
# Processing: image_01374.png
# Processing: image_01375.png
# Processing: image_01376.png
# Processing: image_01377.png
# Processing: image_01378.png
# Processing: image_01379.png
# Processing: image_01380.png
# Processing: image_01381.png
# Processing: image_01382.png
# Processing: image_01383.png
# Processing: image_01384.png
# Processing: image_01385.png
# Processing: image_01386.png
# Processing: image_01387.png
# Processing: image_01388.png
# Processing: image_01389.png
# Processing: image_01390.png
# Processing: image_01391.png
# Processing: image_01392.png
# Processing: image_01393.png
# Processing: image_01394.png
# Processing: image_01395.png
# Processing: image_01396.png
# Processing: image_01397.png
# Processing: image_01398.png
# Processing: image_01399.png
# Processing: image_01400.png
# Processing: image_01401.png
# Processing: image_01402.png
# Processing: image_01403.png
# Processing: image_01404.png
# Processing: image_01405.png
# Processing: image_01406.png
# Processing: image_01407.png
# Processing: image_01408.png
# Processing: image_01409.png
# Processing: image_01410.png
# Processing: image_01411.png
# Processing: image_01412.png
# Processing: image_01413.png
# Processing: image_01414.png
# Processing: image_01415.png
# Processing: image_01416.png
# Processing: image_01417.png
# Processing: image_01418.png
# Processing: image_01419.png
# Processing: image_01420.png
# Processing: image_01421.png
# Processing: image_01422.png
# Processing: image_01423.png
# Processing: image_01424.png
# Processing: image_01425.png
# Processing: image_01426.png
# Processing: image_01427.png
# Processing: image_01428.png
# Processing: image_01429.png
# Processing: image_01430.png
# Processing: image_01431.png
# Processing: image_01432.png
# Processing: image_01433.png
# Processing: image_01434.png
# Processing: image_01435.png
# Processing: image_01436.png
# Processing: image_01437.png
# Processing: image_01438.png
# Processing: image_01439.png
# Processing: image_01440.png
# Processing: image_01441.png
# Processing: image_01442.png
# Processing: image_01443.png
# Processing: image_01444.png
# Processing: image_01445.png
# Processing: image_01446.png
# Processing: image_01447.png
# Processing: image_01448.png
# Processing: image_01449.png
# Processing: image_01450.png
# Processing: image_01451.png
# Processing: image_01452.png
# Processing: image_01453.png
# Processing: image_01454.png
# Processing: image_01455.png
# Processing: image_01456.png
# Processing: image_01457.png
# Processing: image_01458.png
# Processing: image_01459.png
# Processing: image_01460.png
# Processing: image_01461.png
# Processing: image_01462.png
# Processing: image_01463.png
# Processing: image_01464.png
# Processing: image_01465.png
# Processing: image_01466.png
# Processing: image_01467.png
# Processing: image_01468.png
# Processing: image_01469.png
# Processing: image_01470.png
# Processing: image_01471.png
# Processing: image_01472.png
# Processing: image_01473.png
# Processing: image_01474.png
# Processing: image_01475.png
# Processing: image_01476.png
# Processing: image_01477.png
# Processing: image_01478.png
# Processing: image_01479.png
# Processing: image_01480.png
# Processing: image_01481.png
# Processing: image_01482.png
# Processing: image_01483.png
# Processing: image_01484.png
# Processing: image_01485.png
# Processing: image_01486.png
# Processing: image_01487.png
# Processing: image_01488.png
# Processing: image_01489.png
# Processing: image_01490.png
# Processing: image_01491.png
# Processing: image_01492.png
# Processing: image_01493.png
# Processing: image_01494.png
# Processing: image_01495.png
# Processing: image_01496.png
# Processing: image_01497.png
# Processing: image_01498.png
# Processing: image_01499.png
# Processing: image_01500.png
# Processing: image_01501.png
# Processing: image_01502.png
# Processing: image_01503.png
# Processing: image_01504.png
# Processing: image_01505.png
# Processing: image_01506.png
# Processing: image_01507.png
# Processing: image_01508.png
# Processing: image_01509.png
# Processing: image_01510.png
# Processing: image_01511.png
# Processing: image_01512.png
# Processing: image_01513.png
# Processing: image_01514.png
# Processing: image_01515.png
# Processing: image_01516.png
# Processing: image_01517.png
# Processing: image_01518.png
# Processing: image_01519.png
# Processing: image_01520.png
# Processing: image_01521.png
# Processing: image_01522.png
# Processing: image_01523.png
# Processing: image_01524.png
# Processing: image_01525.png
# Processing: image_01526.png
# Processing: image_01527.png
# Processing: image_01528.png
# Processing: image_01529.png
# Processing: image_01530.png
# Processing: image_01531.png
# Processing: image_01532.png
# Processing: image_01533.png
# Processing: image_01534.png
# Processing: image_01535.png
# Processing: image_01536.png
# Processing: image_01537.png
# Processing: image_01538.png
# Processing: image_01539.png
# Processing: image_01540.png
# Processing: image_01541.png
# Processing: image_01542.png
# Processing: image_01543.png
# Processing: image_01544.png
# Processing: image_01545.png
# Processing: image_01546.png
# Processing: image_01547.png
# Processing: image_01548.png
# Processing: image_01549.png
# Processing: image_01550.png
# Processing: image_01551.png
# Processing: image_01552.png
# Processing: image_01553.png
# Processing: image_01554.png
# Processing: image_01555.png
# Processing: image_01556.png
# Processing: image_01557.png
# Processing: image_01558.png
# Processing: image_01559.png
# Processing: image_01560.png
# Processing: image_01561.png
# Processing: image_01562.png
# Processing: image_01563.png
# Processing: image_01564.png
# Processing: image_01565.png
# Processing: image_01566.png
# Processing: image_01567.png
# Processing: image_01568.png
# Processing: image_01569.png
# Processing: image_01570.png
# Processing: image_01571.png
# Processing: image_01572.png
# Processing: image_01573.png
# Processing: image_01574.png
# Processing: image_01575.png
# Processing: image_01576.png
# Processing: image_01577.png
# Processing: image_01578.png
# Processing: image_01579.png
# Processing: image_01580.png
# Processing: image_01581.png
# Processing: image_01582.png
# Processing: image_01583.png
# Processing: image_01584.png
# Processing: image_01585.png
# Processing: image_01586.png
# Processing: image_01587.png
# Processing: image_01588.png
# Processing: image_01589.png
# Processing: image_01590.png
# Processing: image_01591.png
# Processing: image_01592.png
# Processing: image_01593.png
# Processing: image_01594.png
# Processing: image_01595.png
# Processing: image_01596.png
# Processing: image_01597.png
# Processing: image_01598.png
# Processing: image_01599.png
# Processing: image_01600.png
# Processing: image_01601.png
# Processing: image_01602.png
# Processing: image_01603.png
# Processing: image_01604.png
# Processing: image_01605.png
# Processing: image_01606.png
# Processing: image_01607.png
# Processing: image_01608.png
# Processing: image_01609.png
# Processing: image_01610.png
# Processing: image_01611.png
# Processing: image_01612.png
# Processing: image_01613.png
# Processing: image_01614.png
# Processing: image_01615.png
# Processing: image_01616.png
# Processing: image_01617.png
# Processing: image_01618.png
# Processing: image_01619.png
# Processing: image_01620.png
# Processing: image_01621.png
# Processing: image_01622.png
# Processing: image_01623.png
# Processing: image_01624.png
# Processing: image_01625.png
# Processing: image_01626.png
# Processing: image_01627.png
# Processing: image_01628.png
# Processing: image_01629.png
# Processing: image_01630.png
# Processing: image_01631.png
# Processing: image_01632.png
# Processing: image_01633.png
# Processing: image_01634.png
# Processing: image_01635.png
# Processing: image_01636.png
# Processing: image_01637.png
# Processing: image_01638.png
# Processing: image_01639.png
# Processing: image_01640.png
# Processing: image_01641.png
# Processing: image_01642.png
# Processing: image_01643.png
# Processing: image_01644.png
# Processing: image_01645.png
# Processing: image_01646.png
# Processing: image_01647.png
# Processing: image_01648.png
# Processing: image_01649.png
# Processing: image_01650.png
# Processing: image_01651.png
# Processing: image_01652.png
# Processing: image_01653.png
# Processing: image_01654.png
# Processing: image_01655.png
# Processing: image_01656.png
# Processing: image_01657.png
# Processing: image_01658.png
# Processing: image_01659.png
# Processing: image_01660.png
# Processing: image_01661.png
# Processing: image_01662.png
# Processing: image_01663.png
# Processing: image_01664.png
# Processing: image_01665.png
# Processing: image_01666.png
# Processing: image_01667.png
# Processing: image_01668.png
# Processing: image_01669.png
# Processing: image_01670.png
# Processing: image_01671.png
# Processing: image_01672.png
# Processing: image_01673.png
# Processing: image_01674.png
# Processing: image_01675.png
# Processing: image_01676.png
# Processing: image_01677.png
# Processing: image_01678.png
# Processing: image_01679.png
# Processing: image_01680.png
# Processing: image_01681.png
# Processing: image_01682.png
# Processing: image_01683.png
# Processing: image_01684.png
# Processing: image_01685.png
# Processing: image_01686.png
# Processing: image_01687.png
# Processing: image_01688.png
# Processing: image_01689.png
# Processing: image_01690.png
# Processing: image_01691.png
# Processing: image_01692.png
# Processing: image_01693.png
# Processing: image_01694.png
# Processing: image_01695.png
# Processing: image_01696.png
# Processing: image_01697.png
# Processing: image_01698.png
# Processing: image_01699.png
# Processing: image_01700.png
# Processing: image_01701.png
# Processing: image_01702.png
# Processing: image_01703.png
# Processing: image_01704.png
# Processing: image_01705.png
# Processing: image_01706.png
# Processing: image_01707.png
# Processing: image_01708.png
# Processing: image_01709.png
# Processing: image_01710.png
# Processing: image_01711.png
# Processing: image_01712.png
# Processing: image_01713.png
# Processing: image_01714.png
# ...
# Processing: image_01803.png
# Processing: image_01804.png
# Processing: image_01805.png
# Processing: image_01806.png
# Processing: image_01807.png
# Processing: image_01808.png
# Processing: image_01809.png
# Processing: image_01810.png
# Processing: image_01811.png
# Processing: image_01812.png
# Processing: image_01813.png
# Processing: image_01814.png
# Processing: image_01815.png
# Processing: image_01816.png
# Processing: image_01817.png
# Processing: image_01818.png
# Processing: image_01819.png
# Processing: image_01820.png
# Processing: image_01821.png
# Processing: image_01822.png
# Processing: image_01823.png
# Processing: image_01824.png
# Processing: image_01825.png
# Processing: image_01826.png
# Processing: image_01827.png
# Processing: image_01828.png
# Processing: image_01829.png
# Processing: image_01830.png
# Processing: image_01831.png
# Processing: image_01832.png
# Processing: image_01833.png
# Processing: image_01834.png
# Processing: image_01835.png
# Processing: image_01836.png
# Processing: image_01837.png
# Processing: image_01838.png
# Processing: image_01839.png
# Processing: image_01840.png
# Processing: image_01841.png
# Processing: image_01842.png
# Processing: image_01843.png
# Processing: image_01844.png
# Processing: image_01845.png
# Processing: image_01846.png
# Processing: image_01847.png
# Processing: image_01848.png
# Processing: image_01849.png
# Processing: image_01850.png
# Processing: image_01851.png
# Processing: image_01852.png
# Processing: image_01853.png
# Processing: image_01854.png
# Processing: image_01855.png
# Processing: image_01856.png
# Processing: image_01857.png
# Processing: image_01858.png
# Processing: image_01859.png
# Processing: image_01860.png
# Processing: image_01861.png
# Processing: image_01862.png
# Processing: image_01863.png
# Processing: image_01864.png
# Processing: image_01865.png
# Processing: image_01866.png
# Processing: image_01867.png
# Processing: image_01868.png
# Processing: image_01869.png
# Processing: image_01870.png
# Processing: image_01871.png
# Processing: image_01872.png
# Processing: image_01873.png
# Processing: image_01874.png
# Processing: image_01875.png
# Processing: image_01876.png
# Processing: image_01877.png
# Processing: image_01878.png
# Processing: image_01879.png
# Processing: image_01880.png
# Processing: image_01881.png
# Processing: image_01882.png
# Processing: image_01883.png
# Processing: image_01884.png
# Processing: image_01885.png
# Processing: image_01886.png
# Processing: image_01887.png
# Processing: image_01888.png
# Processing: image_01889.png
# Processing: image_01890.png
# Processing: image_01891.png
# Processing: image_01892.png
# Processing: image_01893.png
# Processing: image_01894.png
# Processing: image_01895.png
# Processing: image_01896.png
# Processing: image_01897.png
# Processing: image_01898.png
# Processing: image_01899.png
# Processing: image_01900.png
# Processing: image_01901.png
# Processing: image_01902.png
# Processing: image_01903.png
# Processing: image_01904.png
# Processing: image_01905.png
# Processing: image_01906.png
# Processing: image_01907.png
# Processing: image_01908.png
# Processing: image_01909.png
# Processing: image_01910.png
# Processing: image_01911.png
# Processing: image_01912.png
# Processing: image_01913.png
# Processing: image_01914.png
# Processing: image_01915.png
# Processing: image_01916.png
# Processing: image_01917.png
# Processing: image_01918.png
# Processing: image_01919.png
# Processing: image_01920.png
# Processing: image_01921.png
# Processing: image_01922.png
# Processing: image_01923.png
# Processing: image_01924.png
# Processing: image_01925.png
# Processing: image_01926.png
# Processing: image_01927.png
# Processing: image_01928.png
# Processing: image_01929.png
# Processing: image_01930.png
# Processing: image_01931.png
# Processing: image_01932.png
# Processing: image_01933.png
# Processing: image_01934.png
# Processing: image_01935.png
# Processing: image_01936.png
# Processing: image_01937.png
# Processing: image_01938.png
# Processing: image_01939.png
# Processing: image_01940.png
# Processing: image_01941.png
# Processing: image_01942.png
# Processing: image_01943.png
# Processing: image_01944.png
# Processing: image_01945.png
# Processing: image_01946.png
# Processing: image_01947.png
# Processing: image_01948.png
# Processing: image_01949.png
# Processing: image_01950.png
# Processing: image_01951.png
# Processing: image_01952.png
# Processing: image_01953.png
# Processing: image_01954.png
# Processing: image_01955.png
# Processing: image_01956.png
# Processing: image_01957.png
# Processing: image_01958.png
# Processing: image_01959.png
# Processing: image_01960.png
# Processing: image_01961.png
# Processing: image_01962.png
# Processing: image_01963.png
# Processing: image_01964.png
# Processing: image_01965.png
# Processing: image_01966.png
# Processing: image_01967.png
# Processing: image_01968.png
# Processing: image_01969.png
# Processing: image_01970.png
# Processing: image_01971.png
# Processing: image_01972.png
# Processing: image_01973.png
# Processing: image_01974.png
# Processing: image_01975.png
# Processing: image_01976.png
# Processing: image_01977.png
# Processing: image_01978.png
# Processing: image_01979.png
# Processing: image_01980.png
# Processing: image_01981.png
# Processing: image_01982.png
# Processing: image_01983.png
# Processing: image_01984.png
# Processing: image_01985.png
# Processing: image_01986.png
# Processing: image_01987.png
# Processing: image_01988.png
# Processing: image_01989.png
# Processing: image_01990.png
# Processing: image_01991.png
# Processing: image_01992.png
# Processing: image_01993.png
# Processing: image_01994.png
# Processing: image_01995.png
# Processing: image_01996.png
# Processing: image_01997.png
# Processing: image_01998.png
# Processing: image_01999.png
# Processing: image_02000.png
# Processing: image_02001.png
# Processing: image_02002.png
# Processing: image_02003.png
# Processing: image_02004.png
# Processing: image_02005.png
# Processing: image_02006.png
# Processing: image_02007.png
# Processing: image_02008.png
# Processing: image_02009.png
# Processing: image_02010.png
# Processing: image_02011.png
# Processing: image_02012.png
# Processing: image_02013.png
# Processing: image_02014.png
# Processing: image_02015.png
# Processing: image_02016.png
# Processing: image_02017.png
# Processing: image_02018.png
# Processing: image_02019.png
# Processing: image_02020.png
# Processing: image_02021.png
# Processing: image_02022.png
# Processing: image_02023.png
# Processing: image_02024.png
# Processing: image_02025.png
# Processing: image_02026.png
# Processing: image_02027.png
# Processing: image_02028.png
# Processing: image_02029.png
# Processing: image_02030.png
# Processing: image_02031.png
# Processing: image_02032.png
# Processing: image_02033.png
# Processing: image_02034.png
# Processing: image_02035.png
# Processing: image_02036.png
# Processing: image_02037.png
# Processing: image_02038.png
# Processing: image_02039.png
# Processing: image_02040.png
# Processing: image_02041.png
# Processing: image_02042.png
# Processing: image_02043.png
# Processing: image_02044.png
# Processing: image_02045.png
# Processing: image_02046.png
# Processing: image_02047.png
# Processing: image_02048.png
# Processing: image_02049.png
# Processing: image_02050.png
# Processing: image_02051.png
# Processing: image_02052.png
# Processing: image_02053.png
# Processing: image_02054.png
# Processing: image_02055.png
# Processing: image_02056.png
# Processing: image_02057.png
# Processing: image_02058.png
# Processing: image_02059.png
# Processing: image_02060.png
# Processing: image_02061.png
# Processing: image_02062.png
# Processing: image_02063.png
# Processing: image_02064.png
# Processing: image_02065.png
# Processing: image_02066.png
# Processing: image_02067.png
# Processing: image_02068.png
# Processing: image_02069.png
# Processing: image_02070.png
# Processing: image_02071.png
# Processing: image_02072.png
# Processing: image_02073.png
# Processing: image_02074.png
# Processing: image_02075.png
# Processing: image_02076.png
# Processing: image_02077.png
# Processing: image_02078.png
# Processing: image_02079.png
# Processing: image_02080.png
# Processing: image_02081.png
# Processing: image_02082.png
# Processing: image_02083.png
# Processing: image_02084.png
# Processing: image_02085.png
# Processing: image_02086.png
# Processing: image_02087.png
# Processing: image_02088.png
# Processing: image_02089.png
# Processing: image_02090.png
# Processing: image_02091.png
# Processing: image_02092.png
# Processing: image_02093.png
# Processing: image_02094.png
# Processing: image_02095.png
# Processing: image_02096.png
# Processing: image_02097.png
# Processing: image_02098.png
# Processing: image_02099.png
# Processing: image_02100.png
# Processing: image_02101.png
# Processing: image_02102.png
# Processing: image_02103.png
# Processing: image_02104.png
# Processing: image_02105.png
# Processing: image_02106.png
# Processing: image_02107.png
# Processing: image_02108.png
# Processing: image_02109.png
# Processing: image_02110.png
# Processing: image_02111.png
# Processing: image_02112.png
# Processing: image_02113.png
# Processing: image_02114.png
# Processing: image_02115.png
# Processing: image_02116.png
# Processing: image_02117.png
# Processing: image_02118.png
# Processing: image_02119.png
# Processing: image_02120.png
# Processing: image_02121.png
# Processing: image_02122.png
# Processing: image_02123.png
# Processing: image_02124.png
# Processing: image_02125.png
# Processing: image_02126.png
# Processing: image_02127.png
# Processing: image_02128.png
# Processing: image_02129.png
# Processing: image_02130.png
# Processing: image_02131.png
# Processing: image_02132.png
# Processing: image_02133.png
# Processing: image_02134.png
# Processing: image_02135.png
# Processing: image_02136.png
# Processing: image_02137.png
# Processing: image_02138.png
# Processing: image_02139.png
# Processing: image_02140.png
# Processing: image_02141.png
# Processing: image_02142.png
# Processing: image_02143.png
# Processing: image_02144.png
# Processing: image_02145.png
# Processing: image_02146.png
# Processing: image_02147.png
# Processing: image_02148.png
# Processing: image_02149.png
# Processing: image_02150.png
# Processing: image_02151.png
# Processing: image_02152.png
# Processing: image_02153.png
# Processing: image_02154.png
# Processing: image_02155.png
# Processing: image_02156.png
# Processing: image_02157.png
# Processing: image_02158.png
# Processing: image_02159.png
# Processing: image_02160.png
# Processing: image_02161.png
# Processing: image_02162.png
# Processing: image_02163.png
# Processing: image_02164.png
# Processing: image_02165.png
# Processing: image_02166.png
# Processing: image_02167.png
# Processing: image_02168.png
# Processing: image_02169.png
# Processing: image_02170.png
# Processing: image_02171.png
# Processing: image_02172.png
# Processing: image_02173.png
# Processing: image_02174.png
# Processing: image_02175.png
# Processing: image_02176.png
# Processing: image_02177.png
# Processing: image_02178.png
# Processing: image_02179.png
# Processing: image_02180.png
# Processing: image_02181.png
# Processing: image_02182.png
# Processing: image_02183.png
# Processing: image_02184.png
# Processing: image_02185.png
# Processing: image_02186.png
# Processing: image_02187.png
# Processing: image_02188.png
# Processing: image_02189.png
# Processing: image_02190.png
# Processing: image_02191.png
# Processing: image_02192.png
# Processing: image_02193.png
# Processing: image_02194.png
# Processing: image_02195.png
# Processing: image_02196.png
# Processing: image_02197.png
# Processing: image_02198.png
# Processing: image_02199.png
# Processing: image_02200.png
# Processing: image_02201.png
# Processing: image_02202.png
# Processing: image_02203.png
# Processing: image_02204.png
# Processing: image_02205.png
# Processing: image_02206.png
# Processing: image_02207.png
# Processing: image_02208.png
# Processing: image_02209.png
# Processing: image_02210.png
# Processing: image_02211.png
# Processing: image_02212.png
# Processing: image_02213.png
# Processing: image_02214.png
# Processing: image_02215.png
# Processing: image_02216.png
# Processing: image_02217.png
# Processing: image_02218.png
# Processing: image_02219.png
# Processing: image_02220.png
# Processing: image_02221.png
# Processing: image_02222.png
# Processing: image_02223.png
# Processing: image_02224.png
# Processing: image_02225.png
# Processing: image_02226.png
# Processing: image_02227.png
# Processing: image_02228.png
# Processing: image_02229.png
# Processing: image_02230.png
# Processing: image_02231.png
# Processing: image_02232.png
# Processing: image_02233.png
# Processing: image_02234.png
# Processing: image_02235.png
# Processing: image_02236.png
# Processing: image_02237.png
# Processing: image_02238.png
# Processing: image_02239.png
# Processing: image_02240.png
# Processing: image_02241.png
# Processing: image_02242.png
# Processing: image_02243.png
# Processing: image_02244.png
# Processing: image_02245.png
# Processing: image_02246.png
# Processing: image_02247.png
# Processing: image_02248.png
# Processing: image_02249.png
# Processing: image_02250.png
# Processing: image_02251.png
# Processing: image_02252.png
# Processing: image_02253.png
# Processing: image_02254.png
# Processing: image_02255.png
# Processing: image_02256.png
# Processing: image_02257.png
# Processing: image_02258.png
# Processing: image_02259.png
# Processing: image_02260.png
# Processing: image_02261.png
# Processing: image_02262.png
# Processing: image_02263.png
# Processing: image_02264.png
# Processing: image_02265.png
# Processing: image_02266.png
# Processing: image_02267.png
# Processing: image_02268.png
# Processing: image_02269.png
# Processing: image_02270.png
# Processing: image_02271.png
# Processing: image_02272.png
# Processing: image_02273.png
# Processing: image_02274.png
# Processing: image_02275.png
# Processing: image_02276.png
# Processing: image_02277.png
# Processing: image_02278.png
# Processing: image_02279.png
# Processing: image_02280.png
# Processing: image_02281.png
# Processing: image_02282.png
# Processing: image_02283.png
# Processing: image_02284.png
# Processing: image_02285.png
# Processing: image_02286.png
# Processing: image_02287.png
# Processing: image_02288.png
# Processing: image_02289.png
# Processing: image_02290.png
# Processing: image_02291.png
# Processing: image_02292.png
# Processing: image_02293.png
# Processing: image_02294.png
# Processing: image_02295.png
# Processing: image_02296.png
# Processing: image_02297.png
# Processing: image_02298.png
# Processing: image_02299.png
# Processing: image_02300.png
# Processing: image_02301.png
# Processing: image_02302.png
# Processing: image_02303.png
# Processing: image_02304.png
# Processing: image_02305.png
# Processing: image_02306.png
# Processing: image_02307.png
# Processing: image_02308.png
# Processing: image_02309.png
# Processing: image_02310.png
# Processing: image_02311.png
# Processing: image_02312.png
# Processing: image_02313.png
# Processing: image_02314.png
# Processing: image_02315.png
# Processing: image_02316.png
# Processing: image_02317.png
# Processing: image_02318.png
# Processing: image_02319.png
# Processing: image_02320.png
# Processing: image_02321.png
# Processing: image_02322.png
# Processing: image_02323.png
# Processing: image_02324.png
# Processing: image_02325.png
# Processing: image_02326.png
# Processing: image_02327.png
# Processing: image_02328.png
# Processing: image_02329.png
# Processing: image_02330.png
# Processing: image_02331.png
# Processing: image_02332.png
# Processing: image_02333.png
# Processing: image_02334.png
# Processing: image_02335.png
# Processing: image_02336.png
# Processing: image_02337.png
# Processing: image_02338.png
# Processing: image_02339.png
# Processing: image_02340.png
# Processing: image_02341.png
# Processing: image_02342.png
# Processing: image_02343.png
# Processing: image_02344.png
# Processing: image_02345.png
# Processing: image_02346.png
# Processing: image_02347.png
# Processing: image_02348.png
# Processing: image_02349.png
# Processing: image_02350.png
# Processing: image_02351.png
# Processing: image_02352.png
# Processing: image_02353.png
# Processing: image_02354.png
# Processing: image_02355.png
# Processing: image_02356.png
# Processing: image_02357.png
# Processing: image_02358.png
# Processing: image_02359.png
# Processing: image_02360.png
# Processing: image_02361.png
# Processing: image_02362.png
# Processing: image_02363.png
# Processing: image_02364.png
# Processing: image_02365.png
# Processing: image_02366.png
# Processing: image_02367.png
# Processing: image_02368.png
# ✅ All results saved to: C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\FDIA 1\CNN\stego_images
