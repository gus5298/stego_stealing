# %%
# === IMPORTS ===
import os
import cv2
import numpy as np
import pandas as pd
import random
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib as mpl
import hashlib
import tensorflow as tf
from tensorflow.keras.models import load_model
from skimage.metrics import structural_similarity as ssim
from scipy.fftpack import dct
import math

mpl.rcParams['font.family'] = 'DejaVu Sans'

# %%
# === CONFIGURATION ===
IMG_SIZE = (64, 64)
NUM_PIXELS = 24
MESSAGE_BITS = NUM_PIXELS
CHANNELS = 1
CLASS_NAMES = ['Normal', 'Attack', 'Faulty']
SEED_MODE = 'hash'
SEED_RESERVED_PIXELS = 150
SEED_SECRET_KEY = "my_shared_passphrase"

# %%
# === MESSAGE UTILS ===
def generate_random_message(chars=3):
    return ''.join(random.choices(string.ascii_letters[:26] + string.ascii_letters[26:], k=chars))

def string_to_bits(s):
    return [int(b) for c in s.encode('ascii') for b in format(c, '08b')][:MESSAGE_BITS]

def bits_to_string(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        if len(byte) == 8:
            chars.append(chr(int(''.join(map(str, byte)), 2)))
    return ''.join(chars)

def clean_excel_string(s):
    return ''.join(c for c in s if c.isalpha())

# %%
# === SEED HIDING FUNCTIONS ===
def get_seed_hiding_key(secret_key: str, image: np.ndarray):
    image_hash = hashlib.sha256(image.tobytes()).hexdigest()
    combined = secret_key + image_hash
    digest = hashlib.sha256(combined.encode()).hexdigest()
    return int(digest, 16) % (2**32)

# %%
# === EMBEDDING ===
def embed_lsb(image, bits, coords):
    flat = image.flatten()
    used_indices = set()
    for i, (y, x) in enumerate(coords):
        if not (0 <= y < image.shape[0] and 0 <= x < image.shape[1]):
            continue
        idx = y * image.shape[1] + x
        if idx < SEED_RESERVED_PIXELS:
            continue
        flat[idx] = (flat[idx] & ~1) | bits[i]
        used_indices.add(idx)
    return flat.reshape(image.shape)

# %%
# === SEED EMBEDDING ===
def get_seed_embedding_coords(image, total_reserved=SEED_RESERVED_PIXELS, bits=32, seed_secret_key=SEED_SECRET_KEY):
    seed_key = get_seed_hiding_key(seed_secret_key, image)
    np.random.seed(seed_key)
    coords = np.random.choice(range(total_reserved), size=bits, replace=False)
    return coords

def embed_seed_value(image, seed_bits, seed_secret_key, coords=None):
    if coords is None:
        coords = get_seed_embedding_coords(image.copy(), seed_secret_key=seed_secret_key)
    flat = image.flatten()
    for i, idx in enumerate(coords):
        flat[idx] = (flat[idx] & ~1) | seed_bits[i]
    return flat.reshape(image.shape), coords

def extract_seed_value(image, seed_secret_key, coords=None):
    if coords is None:
        coords = get_seed_embedding_coords(image.copy(), seed_secret_key=seed_secret_key)
    flat = image.flatten()
    seed_bits = [flat[idx] & 1 for idx in coords]
    seed_value = int(''.join(map(str, seed_bits)), 2)
    return seed_value

# %%
# === SEED GENERATORS ===
def get_seed_from_image(secret_key: str, image: np.ndarray):
    image_hash = hashlib.sha256(image.tobytes()).hexdigest()
    combined = secret_key + image_hash + "_main_seed"
    digest = hashlib.sha256(combined.encode()).hexdigest()
    return int(digest, 16) % (2**32)

def get_random_seed():
    return random.randint(0, 2**32 - 1)

# %%
# === PRNG PIXEL SELECTION ===
def generate_prng_pixel_positions(image_shape, count, seed_value):
    np.random.seed(seed_value)
    h, w = image_shape
    total_pixels = h * w
    excluded_pixels = set(range(SEED_RESERVED_PIXELS))
    valid_indices = list(set(range(total_pixels)) - excluded_pixels)
    indices = np.random.choice(valid_indices, size=count, replace=False)
    ys, xs = np.unravel_index(indices, (h, w))
    return list(zip(ys, xs))

# %%
# === CNN ANALYSIS ===
def extract_features(image):
    image = image.astype(np.float32) / 255.0
    image = np.expand_dims(image, axis=-1)
    image = np.expand_dims(image, axis=0)
    return image

def analyze_with_cnn(stego_image, model):
    cnn_input = extract_features(stego_image)
    prediction = model.predict(cnn_input, verbose=0)[0]
    class_index = int(np.argmax(prediction))
    predicted_class = CLASS_NAMES[class_index]
    confidence = float(prediction[class_index])
    print(f"CNN Prediction: {predicted_class} (Confidence: {confidence:.4f})")
    return predicted_class, confidence

# %%
# === IMAGE QUALITY METRICS ===
def calculate_mse(original, stego):
    return np.mean((original.astype(np.float32) - stego.astype(np.float32)) ** 2)

def calculate_psnr(mse, max_pixel=255.0):
    if mse == 0:
        return float('inf')
    return 20 * math.log10(max_pixel / math.sqrt(mse))

def calculate_ssim(original, stego):
    return ssim(original, stego)

def compute_dct_difference(original, stego):
    original_dct = dct(dct(original.T, norm='ortho').T, norm='ortho')
    stego_dct = dct(dct(stego.T, norm='ortho').T, norm='ortho')
    diff = np.abs(original_dct - stego_dct)
    return np.mean(diff), np.max(diff)

# %%
# === DECODING ===
def decode_message(image, coords):
    flat = image.flatten()
    msg_bits = [flat[y * image.shape[1] + x] & 1 for y, x in coords[:NUM_PIXELS]]
    return bits_to_string(msg_bits)

# %%
# === MAIN PROCESSING FUNCTION ===
def process_folder(input_folder, model_path, stego_output_folder, results_output_folder, seed_secret_key):
    model = load_model(model_path)
    results = []

    if not os.path.exists(stego_output_folder):
        os.makedirs(stego_output_folder)

    image_files = [f for f in os.listdir(input_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    for idx, filename in enumerate(image_files):
        print(f"[{idx + 1}/{len(image_files)}] Processing: {filename}")
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image, IMG_SIZE)
        image = image.astype(np.uint8)

        seed_value = get_seed_from_image(seed_secret_key, image)
        seed_bits = [int(b) for b in format(seed_value, '032b')]

        stego_img, seed_coords = embed_seed_value(image.copy(), seed_bits, seed_secret_key)
        extracted_seed = extract_seed_value(stego_img, seed_secret_key, coords=seed_coords)
        key_match_status = "Matched" if extracted_seed == seed_value else "Mismatched"

        prng_pixels = generate_prng_pixel_positions(image.shape, NUM_PIXELS, seed_value)
        original_msg = generate_random_message(chars=3)
        msg_bits = string_to_bits(original_msg)
        final_stego = embed_lsb(stego_img.copy(), msg_bits, prng_pixels)

        decoded_msg = decode_message(final_stego, prng_pixels)
        msg_match_status = "Matched" if clean_excel_string(decoded_msg) == clean_excel_string(original_msg) else "Mismatched"

        pred_class, confidence = analyze_with_cnn(final_stego, model)

        stego_image_filename = f"stego_{filename}"
        stego_image_path = os.path.join(stego_output_folder, stego_image_filename)
        cv2.imwrite(stego_image_path, final_stego)

        mse_value = calculate_mse(image, final_stego)
        psnr_value = calculate_psnr(mse_value)
        ssim_value = calculate_ssim(image, final_stego)
        mean_dct_diff, max_dct_diff = compute_dct_difference(image, final_stego)

        results.append({
            "Image": filename,
            "Original Message": original_msg,
            "Decoded Message": decoded_msg,
            "Message Match": msg_match_status,
            "Seed": seed_value,
            "Extracted Seed": extracted_seed,
            "Key Match": key_match_status,
            "CNN Predicted Class": pred_class,
            "Confidence": confidence,
            "Stego Image Path": stego_image_path,
            "MSE": round(mse_value, 4),
            "PSNR": round(psnr_value, 2),
            "SSIM": round(ssim_value, 4),
            "Mean DCT Diff": round(mean_dct_diff, 4),
            "Max DCT Diff": round(max_dct_diff, 4)
        })

    df = pd.DataFrame(results)
    avg_metrics = {
        "Image": "AVERAGE",
        "MSE": df["MSE"].mean(),
        "PSNR": df["PSNR"].mean(),
        "SSIM": df["SSIM"].mean(),
        "Mean DCT Diff": df["Mean DCT Diff"].mean(),
        "Max DCT Diff": df["Max DCT Diff"].mean()
    }

    if "True Label" not in df.columns:
        df["True Label"] = "Normal"

    df_filtered = df[df["Image"] != "AVERAGE"]
    cm = confusion_matrix(df_filtered["True Label"], df_filtered["CNN Predicted Class"], labels=CLASS_NAMES)

    output_excel = os.path.join(results_output_folder, "stego_analysis_results_with_metrics.xlsx")
    with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:
        df_filtered.to_excel(writer, index=False, sheet_name="Per Image Results")
        pd.DataFrame([avg_metrics]).to_excel(writer, index=False, sheet_name="Summary Averages")

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix for Stego Images")
    plt.tight_layout()
    plt.savefig(os.path.join(results_output_folder, "stego_confusion_matrix.png"))
    plt.close()

    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x="Key Match")
    plt.title("Seed Match Count (Initial PRNG)")
    plt.ylabel("Number of Images")
    plt.xlabel("Key Match Status")
    plt.tight_layout()
    plt.savefig(os.path.join(results_output_folder, "initial_prng_key_match_count.png"))
    plt.close()

    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x="Message Match")
    plt.title("Message Match Count (Second PRNG)")
    plt.ylabel("Number of Images")
    plt.xlabel("Message Match Status")
    plt.tight_layout()
    plt.savefig(os.path.join(results_output_folder, "second_prng_message_match_count.png"))
    plt.close()

    print(f"✅ All results saved to: {results_output_folder}")

# %%
# === RUN ===
input_folder = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\MMS CNN\MMS Images\Attack"
model_path = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\MMS CNN\cnn_3_class_grayscale_model_64x64.h5"
stego_output_folder = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\MMS CNN\stego_images"
results_output_folder = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\MMS CNN\results"
seed_secret_key = "Gustavo_Sanchez"

process_folder(input_folder, model_path, stego_output_folder, results_output_folder, seed_secret_key)
# Out:
# [1/144] Processing: image_00001.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [2/144] Processing: image_00002.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [3/144] Processing: image_00003.png
# CNN Prediction: Attack (Confidence: 0.9989)
# [4/144] Processing: image_00004.png
# CNN Prediction: Attack (Confidence: 0.9432)
# [5/144] Processing: image_00005.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [6/144] Processing: image_00006.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [7/144] Processing: image_00007.png
# CNN Prediction: Attack (Confidence: 0.5698)
# [8/144] Processing: image_00008.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [9/144] Processing: image_00009.png
# CNN Prediction: Attack (Confidence: 0.9997)
# [10/144] Processing: image_00010.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [11/144] Processing: image_00011.png
# CNN Prediction: Attack (Confidence: 0.9995)
# [12/144] Processing: image_00012.png
# CNN Prediction: Normal (Confidence: 1.0000)
# [13/144] Processing: image_00013.png
# CNN Prediction: Attack (Confidence: 0.9971)
# [14/144] Processing: image_00014.png
# CNN Prediction: Attack (Confidence: 0.9993)
# [15/144] Processing: image_00015.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [16/144] Processing: image_00016.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [17/144] Processing: image_00017.png
# CNN Prediction: Normal (Confidence: 0.9903)
# [18/144] Processing: image_00018.png
# CNN Prediction: Attack (Confidence: 0.9992)
# [19/144] Processing: image_00019.png
# CNN Prediction: Attack (Confidence: 0.9988)
# [20/144] Processing: image_00020.png
# CNN Prediction: Attack (Confidence: 0.9995)
# [21/144] Processing: image_00021.png
# CNN Prediction: Attack (Confidence: 0.9997)
# [22/144] Processing: image_00022.png
# CNN Prediction: Faulty (Confidence: 0.7722)
# [23/144] Processing: image_00023.png
# CNN Prediction: Attack (Confidence: 0.9971)
# [24/144] Processing: image_00024.png
# CNN Prediction: Attack (Confidence: 0.9993)
# [25/144] Processing: image_00025.png
# CNN Prediction: Attack (Confidence: 0.9990)
# [26/144] Processing: image_00026.png
# CNN Prediction: Attack (Confidence: 0.9994)
# [27/144] Processing: image_00027.png
# CNN Prediction: Attack (Confidence: 0.5617)
# [28/144] Processing: image_00028.png
# CNN Prediction: Attack (Confidence: 0.9983)
# [29/144] Processing: image_00029.png
# CNN Prediction: Faulty (Confidence: 0.7941)
# [30/144] Processing: image_00030.png
# CNN Prediction: Normal (Confidence: 0.7377)
# [31/144] Processing: image_00031.png
# CNN Prediction: Attack (Confidence: 0.8832)
# [32/144] Processing: image_00032.png
# CNN Prediction: Attack (Confidence: 0.9993)
# [33/144] Processing: image_00033.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [34/144] Processing: image_00034.png
# CNN Prediction: Attack (Confidence: 0.9997)
# [35/144] Processing: image_00035.png
# CNN Prediction: Attack (Confidence: 0.9996)
# [36/144] Processing: image_00036.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [37/144] Processing: image_00037.png
# CNN Prediction: Attack (Confidence: 0.9990)
# [38/144] Processing: image_00038.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [39/144] Processing: image_00039.png
# CNN Prediction: Attack (Confidence: 0.9997)
# [40/144] Processing: image_00040.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [41/144] Processing: image_00041.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [42/144] Processing: image_00042.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [43/144] Processing: image_00043.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [44/144] Processing: image_00044.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [45/144] Processing: image_00045.png
# CNN Prediction: Attack (Confidence: 0.9947)
# [46/144] Processing: image_00046.png
# CNN Prediction: Attack (Confidence: 0.9943)
# [47/144] Processing: image_00047.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [48/144] Processing: image_00048.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [49/144] Processing: image_00049.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [50/144] Processing: image_00050.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [51/144] Processing: image_00051.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [52/144] Processing: image_00052.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [53/144] Processing: image_00053.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [54/144] Processing: image_00054.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [55/144] Processing: image_00055.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [56/144] Processing: image_00056.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [57/144] Processing: image_00057.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [58/144] Processing: image_00058.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [59/144] Processing: image_00059.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [60/144] Processing: image_00060.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [61/144] Processing: image_00061.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [62/144] Processing: image_00062.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [63/144] Processing: image_00063.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [64/144] Processing: image_00064.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [65/144] Processing: image_00065.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [66/144] Processing: image_00066.png
# CNN Prediction: Attack (Confidence: 0.9995)
# [67/144] Processing: image_00067.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [68/144] Processing: image_00068.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [69/144] Processing: image_00069.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [70/144] Processing: image_00070.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [71/144] Processing: image_00071.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [72/144] Processing: image_00072.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [73/144] Processing: image_00073.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [74/144] Processing: image_00074.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [75/144] Processing: image_00075.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [76/144] Processing: image_00076.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [77/144] Processing: image_00077.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [78/144] Processing: image_00078.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [79/144] Processing: image_00079.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [80/144] Processing: image_00080.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [81/144] Processing: image_00081.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [82/144] Processing: image_00082.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [83/144] Processing: image_00083.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [84/144] Processing: image_00084.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [85/144] Processing: image_00085.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [86/144] Processing: image_00086.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [87/144] Processing: image_00087.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [88/144] Processing: image_00088.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [89/144] Processing: image_00089.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [90/144] Processing: image_00090.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [91/144] Processing: image_00091.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [92/144] Processing: image_00092.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [93/144] Processing: image_00093.png
# CNN Prediction: Attack (Confidence: 0.9966)
# [94/144] Processing: image_00094.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [95/144] Processing: image_00095.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [96/144] Processing: image_00096.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [97/144] Processing: image_00097.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [98/144] Processing: image_00098.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [99/144] Processing: image_00099.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [100/144] Processing: image_00100.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [101/144] Processing: image_00101.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [102/144] Processing: image_00102.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [103/144] Processing: image_00103.png
# CNN Prediction: Attack (Confidence: 0.9997)
# [104/144] Processing: image_00104.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [105/144] Processing: image_00105.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [106/144] Processing: image_00106.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [107/144] Processing: image_00107.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [108/144] Processing: image_00108.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [109/144] Processing: image_00109.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [110/144] Processing: image_00110.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [111/144] Processing: image_00111.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [112/144] Processing: image_00112.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [113/144] Processing: image_00113.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [114/144] Processing: image_00114.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [115/144] Processing: image_00115.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [116/144] Processing: image_00116.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [117/144] Processing: image_00117.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [118/144] Processing: image_00118.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [119/144] Processing: image_00119.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [120/144] Processing: image_00120.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [121/144] Processing: image_00121.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [122/144] Processing: image_00122.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [123/144] Processing: image_00123.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [124/144] Processing: image_00124.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [125/144] Processing: image_00125.png
# CNN Prediction: Attack (Confidence: 0.9981)
# [126/144] Processing: image_00126.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [127/144] Processing: image_00127.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [128/144] Processing: image_00128.png
# CNN Prediction: Attack (Confidence: 0.9991)
# [129/144] Processing: image_00129.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [130/144] Processing: image_00130.png
# CNN Prediction: Attack (Confidence: 0.9997)
# [131/144] Processing: image_00131.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [132/144] Processing: image_00132.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [133/144] Processing: image_00133.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [134/144] Processing: image_00134.png
# CNN Prediction: Attack (Confidence: 1.0000)
# [135/144] Processing: image_00135.png
# CNN Prediction: Attack (Confidence: 0.9979)
# [136/144] Processing: image_00136.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [137/144] Processing: image_00137.png
# CNN Prediction: Attack (Confidence: 0.9792)
# [138/144] Processing: image_00138.png
# CNN Prediction: Attack (Confidence: 0.9995)
# [139/144] Processing: image_00139.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [140/144] Processing: image_00140.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [141/144] Processing: image_00141.png
# CNN Prediction: Attack (Confidence: 0.9998)
# [142/144] Processing: image_00142.png
# CNN Prediction: Attack (Confidence: 0.9895)
# [143/144] Processing: image_00143.png
# CNN Prediction: Attack (Confidence: 0.9999)
# [144/144] Processing: image_00144.png
# CNN Prediction: Attack (Confidence: 0.9984)
# ✅ All results saved to: C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Pseudorandom Number Generator (PRNG)\MMS CNN\results
