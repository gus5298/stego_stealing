# %%
import os
import cv2
import numpy as np
import pandas as pd
import random
import string
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from skimage.metrics import structural_similarity as ssim
from scipy.fftpack import dct
import tensorflow as tf
from tensorflow.keras.models import load_model
from tf_keras_vis.saliency import Saliency
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear

# %%
# === CONFIGURATION === #
IMG_SIZE = (64, 64)
NUM_PIXELS = 16
BITS_PER_COORD = 16
RESERVED_BITS = NUM_PIXELS * BITS_PER_COORD * 2
MESSAGE_BITS = 2 * 8
CHANNELS = 1
CLASS_NAMES = ['Normal', 'Attack', 'Faulty']

# %%
# === MESSAGE UTILS === #
def generate_random_message():
    return ''.join(random.choices(string.ascii_letters + string.digits, k=2))

def string_to_bits(s):
    return [int(b) for c in s.encode('utf-8') for b in format(c, '08b')][:MESSAGE_BITS]

def bits_to_string(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        if len(byte) == 8:
            chars.append(chr(int(''.join(map(str, byte)), 2)))
    return ''.join(chars)

# %%
# === COORDINATE CONVERSION === #
def coords_to_bits(coords):
    bits = []
    for y, x in coords:
        yb = format(y, f'0{BITS_PER_COORD}b')
        xb = format(x, f'0{BITS_PER_COORD}b')
        bits.extend(int(b) for b in yb + xb)
    return bits

def bits_to_coords(bits):
    coords = []
    for i in range(0, len(bits), 32):
        y = int(''.join(map(str, bits[i:i+16])), 2)
        x = int(''.join(map(str, bits[i+16:i+32])), 2)
        coords.append((y, x))
    return coords

# %%
# === CLEANING FUNCTION === #
def clean_message(s):
    return ''.join(c for c in s if c.isprintable())

# %%
# === EMBEDDING === #
def embed_lsb(image, bits, coords):
    flat = image.flatten()
    for i, (y, x) in enumerate(coords):
        idx = y * image.shape[1] + x
        flat[idx] = (flat[idx] & ~1) | bits[i]
    return flat.reshape(image.shape)

def embed_metadata(image, meta_bits):
    flat = image.flatten()
    for i in range(len(meta_bits)):
        flat[i] = (flat[i] & ~(1 << 7)) | (meta_bits[i] << 7)
    return flat.reshape(image.shape)

# %%
# === IG-BASED IMPORTANT PIXELS === #
def get_ig_pixels(model, image_tensor, label_index, top_k=NUM_PIXELS):
    def loss_fn(output): return output[:, label_index]
    saliency = Saliency(model, model_modifier=ReplaceToLinear(), clone=True)
    saliency_map = saliency(loss_fn, image_tensor)
    saliency_map = np.abs(saliency_map[0])
    if saliency_map.ndim == 3:
        saliency_map = np.mean(saliency_map, axis=-1)
    flat = saliency_map.flatten()
    indices = np.argsort(flat)[-top_k:]
    ys, xs = np.unravel_index(indices, saliency_map.shape)
    return list(zip(ys, xs))

# %%
# === DECODING === #
def decode_message_and_coords(image):
    flat = image.flatten()
    coord_bits = [(flat[i] >> 7) & 1 for i in range(RESERVED_BITS)]
    coords = bits_to_coords(coord_bits)
    msg_bits = [flat[y * image.shape[1] + x] & 1 for y, x in coords[:NUM_PIXELS]]
    return bits_to_string(msg_bits), coords

# %%
# === QUALITY METRICS === #
def calculate_mse(original, stego):
    return np.mean((original.astype(np.float32) - stego.astype(np.float32)) ** 2)

def calculate_psnr(mse, max_pixel=255.0):
    if mse == 0:
        return float('inf')
    return 20 * math.log10(max_pixel / math.sqrt(mse))

def calculate_ssim(original, stego):
    return ssim(original, stego)

def compute_dct_difference(original, stego):
    original_dct = dct(dct(original.T, norm='ortho').T, norm='ortho')
    stego_dct = dct(dct(stego.T, norm='ortho').T, norm='ortho')
    diff = np.abs(original_dct - stego_dct)
    return np.mean(diff), np.max(diff)

# %%
# === MAIN PROCESSING FUNCTION === #
def process_folder(input_folder, model_path, output_excel, stego_output_folder):
    model = load_model(model_path)
    results = []
    image_files = [f for f in os.listdir(input_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    matched_count = 0
    mismatched_count = 0

    original_labels = []
    original_preds = []

    for idx, filename in enumerate(image_files):
        print(f"[{idx + 1}/{len(image_files)}] Processing {filename}")
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"⚠️ Could not read {filename}. Skipping.")
            continue

        image = cv2.resize(image, IMG_SIZE)
        norm_img = image.astype(np.float32) / 255.0
        input_tensor = np.expand_dims(norm_img, axis=(0, -1))

        pred_probs = model.predict(input_tensor, verbose=0)[0]
        label_index = int(np.argmax(pred_probs))
        true_label = os.path.basename(input_folder)
        if true_label not in CLASS_NAMES:
            true_label = 'Unknown'

        original_labels.append(true_label)
        original_preds.append(CLASS_NAMES[label_index])

        ig_pixels = get_ig_pixels(model, input_tensor, label_index, top_k=NUM_PIXELS)

        original_msg = generate_random_message()
        msg_bits = string_to_bits(original_msg)
        coord_bits = coords_to_bits(ig_pixels)

        msg_encoded_img = embed_lsb(image.copy(), msg_bits, ig_pixels)
        cnn_input = np.expand_dims(msg_encoded_img.astype(np.float32) / 255.0, axis=(0, -1))
        pred_probs_after_lsb = model.predict(cnn_input, verbose=0)[0]
        pred_class_idx = int(np.argmax(pred_probs_after_lsb))
        pred_class = CLASS_NAMES[pred_class_idx] if pred_class_idx < len(CLASS_NAMES) else 'Unknown'
        confidence = float(pred_probs_after_lsb[pred_class_idx])

        final_stego = embed_metadata(msg_encoded_img, coord_bits)
        stego_image_filename = f"stego_{filename}"
        stego_image_path = os.path.join(stego_output_folder, stego_image_filename)
        cv2.imwrite(stego_image_path, final_stego)
        print(f"Stego image saved to {stego_image_path}")

        decoded_msg, decoded_coords = decode_message_and_coords(final_stego)
        original_clean = clean_message(original_msg)
        decoded_clean = clean_message(decoded_msg)

        print(f"Encoded Message: {original_clean}")
        print(f"Decoded Message: {decoded_clean}")
        print(f"Messages Match: {'Matched' if original_clean == decoded_clean else 'Mismatched'}\n")

        if original_clean == decoded_clean:
            matched_count += 1
        else:
            mismatched_count += 1

        mse_value = calculate_mse(image, final_stego)
        psnr_value = calculate_psnr(mse_value)
        ssim_value = calculate_ssim(image, final_stego)
        mean_dct_diff, max_dct_diff = compute_dct_difference(image, final_stego)

        results.append({
            "Image": filename,
            "Original Message": original_clean,
            "Decoded Message": decoded_clean,
            "Match": "Matched" if original_clean == decoded_clean else "Mismatched",
            "CNN Predicted Class": pred_class,
            "Confidence": round(confidence, 4),
            "Encoded Coords": str(ig_pixels),
            "Decoded Coords Match": "Matched" if ig_pixels == decoded_coords else "Mismatched",
            "True Label": true_label,
            "MSE": round(mse_value, 4),
            "PSNR": round(psnr_value, 2),
            "SSIM": round(ssim_value, 4),
            "Mean DCT Diff": round(mean_dct_diff, 4),
            "Max DCT Diff": round(max_dct_diff, 4)
        })

    df = pd.DataFrame(results)
    avg_mse = df["MSE"].mean()
    avg_psnr = df["PSNR"].mean()
    avg_ssim = df["SSIM"].mean()
    avg_dct_mean = df["Mean DCT Diff"].mean()
    avg_dct_max = df["Max DCT Diff"].mean()
    message_match_rate = (df["Match"] == "Matched").mean() * 100
    coord_match_rate = (df["Decoded Coords Match"] == "Matched").mean() * 100
    cnn_accuracy = (df["True Label"] == df["CNN Predicted Class"]).mean() * 100

    summary_data = {
        "Average MSE": [avg_mse],
        "Average PSNR (dB)": [avg_psnr],
        "Average SSIM": [avg_ssim],
        "Average Mean DCT Diff": [avg_dct_mean],
        "Average Max DCT Diff": [avg_dct_max],
        "Message Match Rate (%)": [message_match_rate],
        "Coordinate Match Rate (%)": [coord_match_rate],
        "CNN Accuracy After Embedding (%)": [cnn_accuracy]
    }
    summary_df = pd.DataFrame(summary_data)

    with pd.ExcelWriter(output_excel, engine='openpyxl', mode='w') as writer:
        df.to_excel(writer, index=False, sheet_name='Per Image Results')
        summary_df.to_excel(writer, index=False, sheet_name='Summary Averages')

    print("\n✅ Done! Results saved to", output_excel)
    print("\n📊 AVERAGE METRICS ACROSS ALL IMAGES:")
    for col in summary_df.columns:
        print(f"{col}: {summary_df[col].iloc[0]:.4f}" if isinstance(summary_df[col].iloc[0], float) else f"{col}: {summary_df[col].iloc[0]}")

    # === Visualization === #
    sns.set(style="whitegrid")
    output_dir = os.path.dirname(output_excel)

    cm_original = confusion_matrix(original_labels, original_preds, labels=CLASS_NAMES)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_original, annot=True, fmt='d', cmap="Greens", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix BEFORE Embedding")
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "confusion_matrix_original.png"))
    plt.close()

    cm = confusion_matrix(df["True Label"], df["CNN Predicted Class"], labels=CLASS_NAMES)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix AFTER Embedding")
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "confusion_matrix.png"))
    plt.close()

    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x="Match")
    plt.title("Message Match Count")
    plt.ylabel("Number of Images")
    plt.xlabel("Match Status")
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "message_match_count.png"))
    plt.close()

    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x="Decoded Coords Match")
    plt.title("Coordinate Match Count")
    plt.ylabel("Number of Images")
    plt.xlabel("Coordinate Match Status")
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "coordinate_match_count.png"))
    plt.close()

    pass  # Replace with actual content if needed in notebook

# %%
# === Run === #
if __name__ == "__main__":
    input_folder = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Layered IG LSB\CNN MMS\Normal"
    model_path = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Layered IG LSB\CNN MMS\cnn_3_class_grayscale_model_64x64.h5"
    output_excel = r"C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Layered IG LSB\CNN MMS\ig_layered_stego_results.xlsx"

    # Specify the path for saving stego images
    stego_output_folder = "Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images"

    # Ensure the stego images directory exists
    if not os.path.exists(stego_output_folder):
        os.makedirs(stego_output_folder)

    # Run the process
    process_folder(input_folder, model_path, output_excel, stego_output_folder)
# Out:
# [1/772] Processing image_00001.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00001.png
# Encoded Message: 10
# Decoded Message: 10
# Messages Match: Matched
#
# [2/772] Processing image_00002.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00002.png
# Encoded Message: zD
# Decoded Message: zD
# Messages Match: Matched
#
# [3/772] Processing image_00003.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00003.png
# Encoded Message: Lx
# Decoded Message: Lx
# Messages Match: Matched
#
# [4/772] Processing image_00004.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00004.png
# Encoded Message: qn
# Decoded Message: qn
# Messages Match: Matched
#
# [5/772] Processing image_00005.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00005.png
# Encoded Message: G5
# Decoded Message: G5
# Messages Match: Matched
#
# [6/772] Processing image_00006.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00006.png
# Encoded Message: po
# Decoded Message: po
# Messages Match: Matched
#
# [7/772] Processing image_00007.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00007.png
# Encoded Message: 3H
# Decoded Message: 3H
# Messages Match: Matched
#
# [8/772] Processing image_00008.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00008.png
# Encoded Message: 8h
# Decoded Message: 8h
# Messages Match: Matched
#
# [9/772] Processing image_00009.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00009.png
# Encoded Message: el
# Decoded Message: el
# Messages Match: Matched
#
# [10/772] Processing image_00010.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00010.png
# Encoded Message: 5J
# Decoded Message: 5J
# Messages Match: Matched
#
# [11/772] Processing image_00011.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00011.png
# Encoded Message: GC
# Decoded Message: GC
# Messages Match: Matched
#
# [12/772] Processing image_00012.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00012.png
# Encoded Message: kD
# Decoded Message: kD
# Messages Match: Matched
#
# [13/772] Processing image_00013.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00013.png
# Encoded Message: A4
# Decoded Message: A4
# Messages Match: Matched
#
# [14/772] Processing image_00014.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00014.png
# Encoded Message: 0j
# Decoded Message: 0j
# Messages Match: Matched
#
# [15/772] Processing image_00015.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00015.png
# Encoded Message: rs
# Decoded Message: rs
# Messages Match: Matched
#
# [16/772] Processing image_00016.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00016.png
# Encoded Message: xV
# Decoded Message: xV
# Messages Match: Matched
#
# [17/772] Processing image_00017.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00017.png
# Encoded Message: Ws
# Decoded Message: Ws
# Messages Match: Matched
#
# [18/772] Processing image_00018.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00018.png
# Encoded Message: n2
# Decoded Message: n2
# Messages Match: Matched
#
# [19/772] Processing image_00019.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00019.png
# Encoded Message: tD
# Decoded Message: tD
# Messages Match: Matched
#
# [20/772] Processing image_00020.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00020.png
# Encoded Message: uJ
# Decoded Message: uJ
# Messages Match: Matched
#
# [21/772] Processing image_00021.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00021.png
# Encoded Message: mS
# Decoded Message: mS
# Messages Match: Matched
#
# [22/772] Processing image_00022.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00022.png
# Encoded Message: 3O
# Decoded Message: 3O
# Messages Match: Matched
#
# [23/772] Processing image_00023.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00023.png
# Encoded Message: K6
# Decoded Message: K6
# Messages Match: Matched
#
# [24/772] Processing image_00024.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00024.png
# Encoded Message: BH
# Decoded Message: BH
# Messages Match: Matched
#
# [25/772] Processing image_00025.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00025.png
# Encoded Message: T4
# Decoded Message: T4
# Messages Match: Matched
#
# [26/772] Processing image_00026.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00026.png
# Encoded Message: Lk
# Decoded Message: Lk
# Messages Match: Matched
#
# [27/772] Processing image_00027.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00027.png
# Encoded Message: 6v
# Decoded Message: 6v
# Messages Match: Matched
#
# [28/772] Processing image_00028.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00028.png
# Encoded Message: 67
# Decoded Message: 67
# Messages Match: Matched
#
# [29/772] Processing image_00029.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00029.png
# Encoded Message: XQ
# Decoded Message: XQ
# Messages Match: Matched
#
# [30/772] Processing image_00030.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00030.png
# Encoded Message: Yy
# Decoded Message: Yy
# Messages Match: Matched
#
# [31/772] Processing image_00031.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00031.png
# Encoded Message: AV
# Decoded Message: AV
# Messages Match: Matched
#
# [32/772] Processing image_00032.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00032.png
# Encoded Message: R3
# Decoded Message: R3
# Messages Match: Matched
#
# [33/772] Processing image_00033.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00033.png
# Encoded Message: 9n
# Decoded Message: 9n
# Messages Match: Matched
#
# [34/772] Processing image_00034.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00034.png
# Encoded Message: Je
# Decoded Message: Je
# Messages Match: Matched
#
# [35/772] Processing image_00035.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00035.png
# Encoded Message: ga
# Decoded Message: ga
# Messages Match: Matched
#
# [36/772] Processing image_00036.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00036.png
# Encoded Message: 1V
# Decoded Message: 1V
# Messages Match: Matched
#
# [37/772] Processing image_00037.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00037.png
# Encoded Message: 6X
# Decoded Message: 6X
# Messages Match: Matched
#
# [38/772] Processing image_00038.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00038.png
# Encoded Message: Bn
# Decoded Message: Bn
# Messages Match: Matched
#
# [39/772] Processing image_00039.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00039.png
# Encoded Message: o3
# Decoded Message: o3
# Messages Match: Matched
#
# [40/772] Processing image_00040.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00040.png
# Encoded Message: cj
# Decoded Message: cj
# Messages Match: Matched
#
# [41/772] Processing image_00041.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00041.png
# Encoded Message: DK
# Decoded Message: DK
# Messages Match: Matched
#
# [42/772] Processing image_00042.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00042.png
# Encoded Message: Tk
# Decoded Message: Tk
# Messages Match: Matched
#
# [43/772] Processing image_00043.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00043.png
# Encoded Message: fi
# Decoded Message: fi
# Messages Match: Matched
#
# [44/772] Processing image_00044.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00044.png
# Encoded Message: Tg
# Decoded Message: Tg
# Messages Match: Matched
#
# [45/772] Processing image_00045.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00045.png
# Encoded Message: TV
# Decoded Message: TV
# Messages Match: Matched
#
# [46/772] Processing image_00046.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00046.png
# Encoded Message: KD
# Decoded Message: KD
# Messages Match: Matched
#
# [47/772] Processing image_00047.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00047.png
# Encoded Message: XT
# Decoded Message: XT
# Messages Match: Matched
#
# [48/772] Processing image_00048.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00048.png
# Encoded Message: Wz
# Decoded Message: Wz
# Messages Match: Matched
#
# [49/772] Processing image_00049.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00049.png
# Encoded Message: nc
# Decoded Message: nc
# Messages Match: Matched
#
# [50/772] Processing image_00050.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00050.png
# Encoded Message: UK
# Decoded Message: UK
# Messages Match: Matched
#
# [51/772] Processing image_00051.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00051.png
# Encoded Message: qa
# Decoded Message: qa
# Messages Match: Matched
#
# [52/772] Processing image_00052.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00052.png
# Encoded Message: UO
# Decoded Message: UO
# Messages Match: Matched
#
# [53/772] Processing image_00053.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00053.png
# Encoded Message: sL
# Decoded Message: sL
# Messages Match: Matched
#
# [54/772] Processing image_00054.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00054.png
# Encoded Message: KT
# Decoded Message: KT
# Messages Match: Matched
#
# [55/772] Processing image_00055.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00055.png
# Encoded Message: NR
# Decoded Message: NR
# Messages Match: Matched
#
# [56/772] Processing image_00056.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00056.png
# Encoded Message: EF
# Decoded Message: EF
# Messages Match: Matched
#
# [57/772] Processing image_00057.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00057.png
# Encoded Message: mz
# Decoded Message: mz
# Messages Match: Matched
#
# [58/772] Processing image_00058.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00058.png
# Encoded Message: gc
# Decoded Message: gc
# Messages Match: Matched
#
# [59/772] Processing image_00059.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00059.png
# Encoded Message: 0y
# Decoded Message: 0y
# Messages Match: Matched
#
# [60/772] Processing image_00060.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00060.png
# Encoded Message: Xz
# Decoded Message: Xz
# Messages Match: Matched
#
# [61/772] Processing image_00061.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00061.png
# Encoded Message: ps
# Decoded Message: ps
# Messages Match: Matched
#
# [62/772] Processing image_00062.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00062.png
# Encoded Message: 0b
# Decoded Message: 0b
# Messages Match: Matched
#
# [63/772] Processing image_00063.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00063.png
# Encoded Message: Iz
# Decoded Message: Iz
# Messages Match: Matched
#
# [64/772] Processing image_00064.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00064.png
# Encoded Message: 4E
# Decoded Message: 4E
# Messages Match: Matched
#
# [65/772] Processing image_00065.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00065.png
# Encoded Message: Hz
# Decoded Message: Hz
# Messages Match: Matched
#
# [66/772] Processing image_00066.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00066.png
# Encoded Message: l6
# Decoded Message: l6
# Messages Match: Matched
#
# [67/772] Processing image_00067.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00067.png
# Encoded Message: 6Y
# Decoded Message: 6Y
# Messages Match: Matched
#
# [68/772] Processing image_00068.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00068.png
# Encoded Message: eI
# Decoded Message: eI
# Messages Match: Matched
#
# [69/772] Processing image_00069.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00069.png
# Encoded Message: Rh
# Decoded Message: Rh
# Messages Match: Matched
#
# [70/772] Processing image_00070.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00070.png
# Encoded Message: 9Y
# Decoded Message: 9Y
# Messages Match: Matched
#
# [71/772] Processing image_00071.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00071.png
# Encoded Message: fp
# Decoded Message: fp
# Messages Match: Matched
#
# [72/772] Processing image_00072.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00072.png
# Encoded Message: vQ
# Decoded Message: vQ
# Messages Match: Matched
#
# [73/772] Processing image_00073.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00073.png
# Encoded Message: na
# Decoded Message: na
# Messages Match: Matched
#
# [74/772] Processing image_00074.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00074.png
# Encoded Message: gh
# Decoded Message: gh
# Messages Match: Matched
#
# [75/772] Processing image_00075.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00075.png
# Encoded Message: o0
# Decoded Message: o0
# Messages Match: Matched
#
# [76/772] Processing image_00076.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00076.png
# Encoded Message: 1m
# Decoded Message: 1m
# Messages Match: Matched
#
# [77/772] Processing image_00077.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00077.png
# Encoded Message: i8
# Decoded Message: i8
# Messages Match: Matched
#
# [78/772] Processing image_00078.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00078.png
# Encoded Message: Pq
# Decoded Message: Pq
# Messages Match: Matched
#
# [79/772] Processing image_00079.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00079.png
# Encoded Message: aM
# Decoded Message: aM
# Messages Match: Matched
#
# [80/772] Processing image_00080.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00080.png
# Encoded Message: DC
# Decoded Message: DC
# Messages Match: Matched
#
# [81/772] Processing image_00081.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00081.png
# Encoded Message: rA
# Decoded Message: rA
# Messages Match: Matched
#
# [82/772] Processing image_00082.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00082.png
# Encoded Message: 0v
# Decoded Message: 0v
# Messages Match: Matched
#
# [83/772] Processing image_00083.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00083.png
# Encoded Message: CR
# Decoded Message: CR
# Messages Match: Matched
#
# [84/772] Processing image_00084.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00084.png
# Encoded Message: jW
# Decoded Message: jW
# Messages Match: Matched
#
# [85/772] Processing image_00085.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00085.png
# Encoded Message: 58
# Decoded Message: 58
# Messages Match: Matched
#
# [86/772] Processing image_00086.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00086.png
# Encoded Message: G3
# Decoded Message: G3
# Messages Match: Matched
#
# [87/772] Processing image_00087.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00087.png
# Encoded Message: 3b
# Decoded Message: 3b
# Messages Match: Matched
#
# [88/772] Processing image_00088.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00088.png
# Encoded Message: 4t
# Decoded Message: 4t
# Messages Match: Matched
#
# [89/772] Processing image_00089.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00089.png
# Encoded Message: 37
# Decoded Message: 37
# Messages Match: Matched
#
# [90/772] Processing image_00090.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00090.png
# Encoded Message: LA
# Decoded Message: LA
# Messages Match: Matched
#
# [91/772] Processing image_00091.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00091.png
# Encoded Message: B9
# Decoded Message: B9
# Messages Match: Matched
#
# [92/772] Processing image_00092.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00092.png
# Encoded Message: fb
# Decoded Message: fb
# Messages Match: Matched
#
# [93/772] Processing image_00093.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00093.png
# Encoded Message: Fc
# Decoded Message: Fc
# Messages Match: Matched
#
# [94/772] Processing image_00094.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00094.png
# Encoded Message: zc
# Decoded Message: zc
# Messages Match: Matched
#
# [95/772] Processing image_00095.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00095.png
# Encoded Message: se
# Decoded Message: se
# Messages Match: Matched
#
# [96/772] Processing image_00096.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00096.png
# Encoded Message: iC
# Decoded Message: iC
# Messages Match: Matched
#
# [97/772] Processing image_00097.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00097.png
# Encoded Message: 1x
# Decoded Message: 1x
# Messages Match: Matched
#
# [98/772] Processing image_00098.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00098.png
# Encoded Message: 9m
# Decoded Message: 9m
# Messages Match: Matched
#
# [99/772] Processing image_00099.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00099.png
# Encoded Message: mX
# Decoded Message: mX
# Messages Match: Matched
#
# [100/772] Processing image_00100.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00100.png
# Encoded Message: G5
# Decoded Message: G5
# Messages Match: Matched
#
# [101/772] Processing image_00101.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00101.png
# Encoded Message: sQ
# Decoded Message: sQ
# Messages Match: Matched
#
# [102/772] Processing image_00102.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00102.png
# Encoded Message: uI
# Decoded Message: uI
# Messages Match: Matched
#
# [103/772] Processing image_00103.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00103.png
# Encoded Message: eb
# Decoded Message: eb
# Messages Match: Matched
#
# [104/772] Processing image_00104.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00104.png
# Encoded Message: Tf
# Decoded Message: Tf
# Messages Match: Matched
#
# [105/772] Processing image_00105.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00105.png
# Encoded Message: vO
# Decoded Message: vO
# Messages Match: Matched
#
# [106/772] Processing image_00106.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00106.png
# Encoded Message: DN
# Decoded Message: DN
# Messages Match: Matched
#
# [107/772] Processing image_00107.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00107.png
# Encoded Message: yV
# Decoded Message: yV
# Messages Match: Matched
#
# [108/772] Processing image_00108.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00108.png
# Encoded Message: 0l
# Decoded Message: 0l
# Messages Match: Matched
#
# [109/772] Processing image_00109.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00109.png
# Encoded Message: B4
# Decoded Message: B4
# Messages Match: Matched
#
# [110/772] Processing image_00110.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00110.png
# Encoded Message: 2i
# Decoded Message: 2i
# Messages Match: Matched
#
# [111/772] Processing image_00111.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00111.png
# Encoded Message: 6q
# Decoded Message: 6q
# Messages Match: Matched
#
# [112/772] Processing image_00112.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00112.png
# Encoded Message: Ww
# Decoded Message: Ww
# Messages Match: Matched
#
# [113/772] Processing image_00113.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00113.png
# Encoded Message: FS
# Decoded Message: FS
# Messages Match: Matched
#
# [114/772] Processing image_00114.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00114.png
# Encoded Message: zz
# Decoded Message: zz
# Messages Match: Matched
#
# [115/772] Processing image_00115.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00115.png
# Encoded Message: 3c
# Decoded Message: 3c
# Messages Match: Matched
#
# [116/772] Processing image_00116.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00116.png
# Encoded Message: pK
# Decoded Message: pK
# Messages Match: Matched
#
# [117/772] Processing image_00117.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00117.png
# Encoded Message: f6
# Decoded Message: f6
# Messages Match: Matched
#
# [118/772] Processing image_00118.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00118.png
# Encoded Message: rn
# Decoded Message: rn
# Messages Match: Matched
#
# [119/772] Processing image_00119.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00119.png
# Encoded Message: ir
# Decoded Message: ir
# Messages Match: Matched
#
# [120/772] Processing image_00120.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00120.png
# Encoded Message: cs
# Decoded Message: cs
# Messages Match: Matched
#
# [121/772] Processing image_00121.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00121.png
# Encoded Message: bI
# Decoded Message: bI
# Messages Match: Matched
#
# [122/772] Processing image_00122.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00122.png
# Encoded Message: rL
# Decoded Message: rL
# Messages Match: Matched
#
# [123/772] Processing image_00123.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00123.png
# Encoded Message: k9
# Decoded Message: k9
# Messages Match: Matched
#
# [124/772] Processing image_00124.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00124.png
# Encoded Message: oC
# Decoded Message: oC
# Messages Match: Matched
#
# [125/772] Processing image_00125.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00125.png
# Encoded Message: 2B
# Decoded Message: 2B
# Messages Match: Matched
#
# [126/772] Processing image_00126.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00126.png
# Encoded Message: 4L
# Decoded Message: 4L
# Messages Match: Matched
#
# [127/772] Processing image_00127.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00127.png
# Encoded Message: UX
# Decoded Message: UX
# Messages Match: Matched
#
# [128/772] Processing image_00128.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00128.png
# Encoded Message: um
# Decoded Message: um
# Messages Match: Matched
#
# [129/772] Processing image_00129.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00129.png
# Encoded Message: 7O
# Decoded Message: 7O
# Messages Match: Matched
#
# [130/772] Processing image_00130.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00130.png
# Encoded Message: c6
# Decoded Message: c6
# Messages Match: Matched
#
# [131/772] Processing image_00131.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00131.png
# Encoded Message: B3
# Decoded Message: B3
# Messages Match: Matched
#
# [132/772] Processing image_00132.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00132.png
# Encoded Message: xF
# Decoded Message: xF
# Messages Match: Matched
#
# [133/772] Processing image_00133.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00133.png
# Encoded Message: ZA
# Decoded Message: ZA
# Messages Match: Matched
#
# [134/772] Processing image_00134.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00134.png
# Encoded Message: em
# Decoded Message: em
# Messages Match: Matched
#
# [135/772] Processing image_00135.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00135.png
# Encoded Message: Oy
# Decoded Message: Oy
# Messages Match: Matched
#
# [136/772] Processing image_00136.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00136.png
# Encoded Message: 5W
# Decoded Message: 5W
# Messages Match: Matched
#
# [137/772] Processing image_00137.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00137.png
# Encoded Message: gj
# Decoded Message: gj
# Messages Match: Matched
#
# [138/772] Processing image_00138.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00138.png
# Encoded Message: Sc
# Decoded Message: Sc
# Messages Match: Matched
#
# [139/772] Processing image_00139.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00139.png
# Encoded Message: 5X
# Decoded Message: 5X
# Messages Match: Matched
#
# [140/772] Processing image_00140.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00140.png
# Encoded Message: ft
# Decoded Message: ft
# Messages Match: Matched
#
# [141/772] Processing image_00141.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00141.png
# Encoded Message: J2
# Decoded Message: J2
# Messages Match: Matched
#
# [142/772] Processing image_00142.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00142.png
# Encoded Message: 2e
# Decoded Message: 2e
# Messages Match: Matched
#
# [143/772] Processing image_00143.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00143.png
# Encoded Message: yG
# Decoded Message: yG
# Messages Match: Matched
#
# [144/772] Processing image_00144.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00144.png
# Encoded Message: Rt
# Decoded Message: Rt
# Messages Match: Matched
#
# [145/772] Processing image_00145.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00145.png
# Encoded Message: Du
# Decoded Message: Du
# Messages Match: Matched
#
# [146/772] Processing image_00146.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00146.png
# Encoded Message: al
# Decoded Message: al
# Messages Match: Matched
#
# [147/772] Processing image_00147.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00147.png
# Encoded Message: nF
# Decoded Message: nF
# Messages Match: Matched
#
# [148/772] Processing image_00148.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00148.png
# Encoded Message: oS
# Decoded Message: oS
# Messages Match: Matched
#
# [149/772] Processing image_00149.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00149.png
# Encoded Message: sL
# Decoded Message: sL
# Messages Match: Matched
#
# [150/772] Processing image_00150.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00150.png
# Encoded Message: Va
# Decoded Message: Va
# Messages Match: Matched
#
# [151/772] Processing image_00151.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00151.png
# Encoded Message: 4c
# Decoded Message: 4c
# Messages Match: Matched
#
# [152/772] Processing image_00152.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00152.png
# Encoded Message: gR
# Decoded Message: gR
# Messages Match: Matched
#
# [153/772] Processing image_00153.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00153.png
# Encoded Message: UP
# Decoded Message: UP
# Messages Match: Matched
#
# [154/772] Processing image_00154.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00154.png
# Encoded Message: ue
# Decoded Message: ue
# Messages Match: Matched
#
# [155/772] Processing image_00155.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00155.png
# Encoded Message: lV
# Decoded Message: lV
# Messages Match: Matched
#
# [156/772] Processing image_00156.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00156.png
# Encoded Message: ZP
# Decoded Message: ZP
# Messages Match: Matched
#
# [157/772] Processing image_00157.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00157.png
# Encoded Message: Ar
# Decoded Message: Ar
# Messages Match: Matched
#
# [158/772] Processing image_00158.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00158.png
# Encoded Message: xX
# Decoded Message: xX
# Messages Match: Matched
#
# [159/772] Processing image_00159.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00159.png
# Encoded Message: PR
# Decoded Message: PR
# Messages Match: Matched
#
# [160/772] Processing image_00160.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00160.png
# Encoded Message: fV
# Decoded Message: fV
# Messages Match: Matched
#
# [161/772] Processing image_00161.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00161.png
# Encoded Message: ke
# Decoded Message: ke
# Messages Match: Matched
#
# [162/772] Processing image_00162.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00162.png
# Encoded Message: fg
# Decoded Message: fg
# Messages Match: Matched
#
# [163/772] Processing image_00163.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00163.png
# Encoded Message: Xh
# Decoded Message: Xh
# Messages Match: Matched
#
# [164/772] Processing image_00164.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00164.png
# Encoded Message: 9E
# Decoded Message: 9E
# Messages Match: Matched
#
# [165/772] Processing image_00165.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00165.png
# Encoded Message: Oe
# Decoded Message: Oe
# Messages Match: Matched
#
# [166/772] Processing image_00166.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00166.png
# Encoded Message: Tz
# Decoded Message: Tz
# Messages Match: Matched
#
# [167/772] Processing image_00167.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00167.png
# Encoded Message: mx
# Decoded Message: mx
# Messages Match: Matched
#
# [168/772] Processing image_00168.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00168.png
# Encoded Message: PD
# Decoded Message: PD
# Messages Match: Matched
#
# [169/772] Processing image_00169.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00169.png
# Encoded Message: N3
# Decoded Message: N3
# Messages Match: Matched
#
# [170/772] Processing image_00170.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00170.png
# Encoded Message: Ye
# Decoded Message: Ye
# Messages Match: Matched
#
# [171/772] Processing image_00171.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00171.png
# Encoded Message: C8
# Decoded Message: C8
# Messages Match: Matched
#
# [172/772] Processing image_00172.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00172.png
# Encoded Message: di
# Decoded Message: di
# Messages Match: Matched
#
# [173/772] Processing image_00173.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00173.png
# Encoded Message: to
# Decoded Message: to
# Messages Match: Matched
#
# [174/772] Processing image_00174.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00174.png
# Encoded Message: Ym
# Decoded Message: Ym
# Messages Match: Matched
#
# [175/772] Processing image_00175.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00175.png
# Encoded Message: O0
# Decoded Message: O0
# Messages Match: Matched
#
# [176/772] Processing image_00176.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00176.png
# Encoded Message: x1
# Decoded Message: x1
# Messages Match: Matched
#
# [177/772] Processing image_00177.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00177.png
# Encoded Message: 4L
# Decoded Message: 4L
# Messages Match: Matched
#
# [178/772] Processing image_00178.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00178.png
# Encoded Message: pB
# Decoded Message: pB
# Messages Match: Matched
#
# [179/772] Processing image_00179.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00179.png
# Encoded Message: ID
# Decoded Message: ID
# Messages Match: Matched
#
# [180/772] Processing image_00180.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00180.png
# Encoded Message: 6G
# Decoded Message: 6G
# Messages Match: Matched
#
# [181/772] Processing image_00181.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00181.png
# Encoded Message: AL
# Decoded Message: AL
# Messages Match: Matched
#
# [182/772] Processing image_00182.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00182.png
# Encoded Message: Qd
# Decoded Message: Qd
# Messages Match: Matched
#
# [183/772] Processing image_00183.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00183.png
# Encoded Message: UA
# Decoded Message: UA
# Messages Match: Matched
#
# [184/772] Processing image_00184.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00184.png
# Encoded Message: 43
# Decoded Message: 43
# Messages Match: Matched
#
# [185/772] Processing image_00185.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00185.png
# Encoded Message: PH
# Decoded Message: PH
# Messages Match: Matched
#
# [186/772] Processing image_00186.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00186.png
# Encoded Message: 43
# Decoded Message: 43
# Messages Match: Matched
#
# [187/772] Processing image_00187.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00187.png
# Encoded Message: bW
# Decoded Message: bW
# Messages Match: Matched
#
# [188/772] Processing image_00188.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00188.png
# Encoded Message: 2C
# Decoded Message: 2C
# Messages Match: Matched
#
# [189/772] Processing image_00189.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00189.png
# Encoded Message: r8
# Decoded Message: r8
# Messages Match: Matched
#
# [190/772] Processing image_00190.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00190.png
# Encoded Message: M8
# Decoded Message: M8
# Messages Match: Matched
#
# [191/772] Processing image_00191.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00191.png
# Encoded Message: MH
# Decoded Message: MH
# Messages Match: Matched
#
# [192/772] Processing image_00192.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00192.png
# Encoded Message: 1O
# Decoded Message: 1O
# Messages Match: Matched
#
# [193/772] Processing image_00193.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00193.png
# Encoded Message: zn
# Decoded Message: zn
# Messages Match: Matched
#
# [194/772] Processing image_00194.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00194.png
# Encoded Message: V1
# Decoded Message: V1
# Messages Match: Matched
#
# [195/772] Processing image_00195.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00195.png
# Encoded Message: xM
# Decoded Message: xM
# Messages Match: Matched
#
# [196/772] Processing image_00196.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00196.png
# Encoded Message: rf
# Decoded Message: rf
# Messages Match: Matched
#
# [197/772] Processing image_00197.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00197.png
# Encoded Message: 43
# Decoded Message: 43
# Messages Match: Matched
#
# [198/772] Processing image_00198.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00198.png
# Encoded Message: HX
# Decoded Message: HX
# Messages Match: Matched
#
# [199/772] Processing image_00199.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00199.png
# Encoded Message: 0F
# Decoded Message: 0F
# Messages Match: Matched
#
# [200/772] Processing image_00200.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00200.png
# Encoded Message: lY
# Decoded Message: lY
# Messages Match: Matched
#
# [201/772] Processing image_00201.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00201.png
# Encoded Message: xF
# Decoded Message: xF
# Messages Match: Matched
#
# [202/772] Processing image_00202.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00202.png
# Encoded Message: o6
# Decoded Message: o6
# Messages Match: Matched
#
# [203/772] Processing image_00203.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00203.png
# Encoded Message: nq
# Decoded Message: nq
# Messages Match: Matched
#
# [204/772] Processing image_00204.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00204.png
# Encoded Message: jo
# Decoded Message: jo
# Messages Match: Matched
#
# [205/772] Processing image_00205.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00205.png
# Encoded Message: uh
# Decoded Message: uh
# Messages Match: Matched
#
# [206/772] Processing image_00206.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00206.png
# Encoded Message: Wg
# Decoded Message: Wg
# Messages Match: Matched
#
# [207/772] Processing image_00207.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00207.png
# Encoded Message: e6
# Decoded Message: e6
# Messages Match: Matched
#
# [208/772] Processing image_00208.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00208.png
# Encoded Message: 3F
# Decoded Message: 3F
# Messages Match: Matched
#
# [209/772] Processing image_00209.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00209.png
# Encoded Message: 9E
# Decoded Message: 9E
# Messages Match: Matched
#
# [210/772] Processing image_00210.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00210.png
# Encoded Message: vk
# Decoded Message: vk
# Messages Match: Matched
#
# [211/772] Processing image_00211.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00211.png
# Encoded Message: W3
# Decoded Message: W3
# Messages Match: Matched
#
# [212/772] Processing image_00212.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00212.png
# Encoded Message: M4
# Decoded Message: M4
# Messages Match: Matched
#
# [213/772] Processing image_00213.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00213.png
# Encoded Message: kv
# Decoded Message: kv
# Messages Match: Matched
#
# [214/772] Processing image_00214.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00214.png
# Encoded Message: te
# Decoded Message: te
# Messages Match: Matched
#
# [215/772] Processing image_00215.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00215.png
# Encoded Message: gW
# Decoded Message: gW
# Messages Match: Matched
#
# [216/772] Processing image_00216.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00216.png
# Encoded Message: BE
# Decoded Message: BE
# Messages Match: Matched
#
# [217/772] Processing image_00217.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00217.png
# Encoded Message: FV
# Decoded Message: FV
# Messages Match: Matched
#
# [218/772] Processing image_00218.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00218.png
# Encoded Message: 4i
# Decoded Message: 4i
# Messages Match: Matched
#
# [219/772] Processing image_00219.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00219.png
# Encoded Message: xu
# Decoded Message: xu
# Messages Match: Matched
#
# [220/772] Processing image_00220.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00220.png
# Encoded Message: EQ
# Decoded Message: EQ
# Messages Match: Matched
#
# [221/772] Processing image_00221.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00221.png
# Encoded Message: GN
# Decoded Message: GN
# Messages Match: Matched
#
# [222/772] Processing image_00222.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00222.png
# Encoded Message: gf
# Decoded Message: gf
# Messages Match: Matched
#
# [223/772] Processing image_00223.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00223.png
# Encoded Message: CN
# Decoded Message: CN
# Messages Match: Matched
#
# [224/772] Processing image_00224.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00224.png
# Encoded Message: hC
# Decoded Message: hC
# Messages Match: Matched
#
# [225/772] Processing image_00225.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00225.png
# Encoded Message: w3
# Decoded Message: w3
# Messages Match: Matched
#
# [226/772] Processing image_00226.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00226.png
# Encoded Message: Mn
# Decoded Message: Mn
# Messages Match: Matched
#
# [227/772] Processing image_00227.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00227.png
# Encoded Message: OS
# Decoded Message: OS
# Messages Match: Matched
#
# [228/772] Processing image_00228.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00228.png
# Encoded Message: At
# Decoded Message: At
# Messages Match: Matched
#
# [229/772] Processing image_00229.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00229.png
# Encoded Message: mw
# Decoded Message: mw
# Messages Match: Matched
#
# [230/772] Processing image_00230.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00230.png
# Encoded Message: gY
# Decoded Message: gY
# Messages Match: Matched
#
# [231/772] Processing image_00231.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00231.png
# Encoded Message: r6
# Decoded Message: r6
# Messages Match: Matched
#
# [232/772] Processing image_00232.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00232.png
# Encoded Message: RK
# Decoded Message: RK
# Messages Match: Matched
#
# [233/772] Processing image_00233.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00233.png
# Encoded Message: j8
# Decoded Message: j8
# Messages Match: Matched
#
# [234/772] Processing image_00234.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00234.png
# Encoded Message: DU
# Decoded Message: DU
# Messages Match: Matched
#
# [235/772] Processing image_00235.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00235.png
# Encoded Message: pt
# Decoded Message: pt
# Messages Match: Matched
#
# [236/772] Processing image_00236.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00236.png
# Encoded Message: Cl
# ...
# Encoded Message: NO
# Decoded Message: NO
# Messages Match: Matched
#
# [697/772] Processing image_00697.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00697.png
# Encoded Message: u2
# Decoded Message: u2
# Messages Match: Matched
#
# [698/772] Processing image_00698.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00698.png
# Encoded Message: sy
# Decoded Message: sy
# Messages Match: Matched
#
# [699/772] Processing image_00699.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00699.png
# Encoded Message: bt
# Decoded Message: bt
# Messages Match: Matched
#
# [700/772] Processing image_00700.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00700.png
# Encoded Message: Rg
# Decoded Message: Rg
# Messages Match: Matched
#
# [701/772] Processing image_00701.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00701.png
# Encoded Message: p8
# Decoded Message: p8
# Messages Match: Matched
#
# [702/772] Processing image_00702.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00702.png
# Encoded Message: 3m
# Decoded Message: 3m
# Messages Match: Matched
#
# [703/772] Processing image_00703.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00703.png
# Encoded Message: 7q
# Decoded Message: 7q
# Messages Match: Matched
#
# [704/772] Processing image_00704.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00704.png
# Encoded Message: NV
# Decoded Message: NV
# Messages Match: Matched
#
# [705/772] Processing image_00705.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00705.png
# Encoded Message: AI
# Decoded Message: AI
# Messages Match: Matched
#
# [706/772] Processing image_00706.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00706.png
# Encoded Message: i0
# Decoded Message: i0
# Messages Match: Matched
#
# [707/772] Processing image_00707.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00707.png
# Encoded Message: HI
# Decoded Message: HI
# Messages Match: Matched
#
# [708/772] Processing image_00708.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00708.png
# Encoded Message: IM
# Decoded Message: IM
# Messages Match: Matched
#
# [709/772] Processing image_00709.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00709.png
# Encoded Message: BI
# Decoded Message: BI
# Messages Match: Matched
#
# [710/772] Processing image_00710.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00710.png
# Encoded Message: c7
# Decoded Message: c7
# Messages Match: Matched
#
# [711/772] Processing image_00711.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00711.png
# Encoded Message: o0
# Decoded Message: o0
# Messages Match: Matched
#
# [712/772] Processing image_00712.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00712.png
# Encoded Message: CC
# Decoded Message: CC
# Messages Match: Matched
#
# [713/772] Processing image_00713.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00713.png
# Encoded Message: bT
# Decoded Message: bT
# Messages Match: Matched
#
# [714/772] Processing image_00714.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00714.png
# Encoded Message: yJ
# Decoded Message: yJ
# Messages Match: Matched
#
# [715/772] Processing image_00715.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00715.png
# Encoded Message: Kf
# Decoded Message: Kf
# Messages Match: Matched
#
# [716/772] Processing image_00716.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00716.png
# Encoded Message: wg
# Decoded Message: wg
# Messages Match: Matched
#
# [717/772] Processing image_00717.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00717.png
# Encoded Message: VY
# Decoded Message: VY
# Messages Match: Matched
#
# [718/772] Processing image_00718.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00718.png
# Encoded Message: Ln
# Decoded Message: Ln
# Messages Match: Matched
#
# [719/772] Processing image_00719.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00719.png
# Encoded Message: e1
# Decoded Message: e1
# Messages Match: Matched
#
# [720/772] Processing image_00720.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00720.png
# Encoded Message: eR
# Decoded Message: eR
# Messages Match: Matched
#
# [721/772] Processing image_00721.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00721.png
# Encoded Message: F9
# Decoded Message: F9
# Messages Match: Matched
#
# [722/772] Processing image_00722.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00722.png
# Encoded Message: PV
# Decoded Message: PV
# Messages Match: Matched
#
# [723/772] Processing image_00723.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00723.png
# Encoded Message: Qu
# Decoded Message: Qu
# Messages Match: Matched
#
# [724/772] Processing image_00724.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00724.png
# Encoded Message: H7
# Decoded Message: H7
# Messages Match: Matched
#
# [725/772] Processing image_00725.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00725.png
# Encoded Message: DQ
# Decoded Message: DQ
# Messages Match: Matched
#
# [726/772] Processing image_00726.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00726.png
# Encoded Message: dF
# Decoded Message: dF
# Messages Match: Matched
#
# [727/772] Processing image_00727.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00727.png
# Encoded Message: dq
# Decoded Message: dq
# Messages Match: Matched
#
# [728/772] Processing image_00728.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00728.png
# Encoded Message: PG
# Decoded Message: PG
# Messages Match: Matched
#
# [729/772] Processing image_00729.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00729.png
# Encoded Message: Wc
# Decoded Message: Wc
# Messages Match: Matched
#
# [730/772] Processing image_00730.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00730.png
# Encoded Message: Ih
# Decoded Message: Ih
# Messages Match: Matched
#
# [731/772] Processing image_00731.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00731.png
# Encoded Message: V5
# Decoded Message: V5
# Messages Match: Matched
#
# [732/772] Processing image_00732.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00732.png
# Encoded Message: JV
# Decoded Message: JV
# Messages Match: Matched
#
# [733/772] Processing image_00733.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00733.png
# Encoded Message: Gr
# Decoded Message: Gr
# Messages Match: Matched
#
# [734/772] Processing image_00734.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00734.png
# Encoded Message: I3
# Decoded Message: I3
# Messages Match: Matched
#
# [735/772] Processing image_00735.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00735.png
# Encoded Message: nl
# Decoded Message: nl
# Messages Match: Matched
#
# [736/772] Processing image_00736.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00736.png
# Encoded Message: Hv
# Decoded Message: Hv
# Messages Match: Matched
#
# [737/772] Processing image_00737.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00737.png
# Encoded Message: Dr
# Decoded Message: Dr
# Messages Match: Matched
#
# [738/772] Processing image_00738.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00738.png
# Encoded Message: Px
# Decoded Message: Px
# Messages Match: Matched
#
# [739/772] Processing image_00739.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00739.png
# Encoded Message: 2Q
# Decoded Message: 2Q
# Messages Match: Matched
#
# [740/772] Processing image_00740.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00740.png
# Encoded Message: sA
# Decoded Message: sA
# Messages Match: Matched
#
# [741/772] Processing image_00741.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00741.png
# Encoded Message: vb
# Decoded Message: vb
# Messages Match: Matched
#
# [742/772] Processing image_00742.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00742.png
# Encoded Message: lJ
# Decoded Message: lJ
# Messages Match: Matched
#
# [743/772] Processing image_00743.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00743.png
# Encoded Message: F3
# Decoded Message: F3
# Messages Match: Matched
#
# [744/772] Processing image_00744.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00744.png
# Encoded Message: uN
# Decoded Message: uN
# Messages Match: Matched
#
# [745/772] Processing image_00745.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00745.png
# Encoded Message: tl
# Decoded Message: tl
# Messages Match: Matched
#
# [746/772] Processing image_00746.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00746.png
# Encoded Message: QK
# Decoded Message: QK
# Messages Match: Matched
#
# [747/772] Processing image_00747.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00747.png
# Encoded Message: a7
# Decoded Message: a7
# Messages Match: Matched
#
# [748/772] Processing image_00748.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00748.png
# Encoded Message: 51
# Decoded Message: 51
# Messages Match: Matched
#
# [749/772] Processing image_00749.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00749.png
# Encoded Message: 2x
# Decoded Message: 2x
# Messages Match: Matched
#
# [750/772] Processing image_00750.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00750.png
# Encoded Message: Ol
# Decoded Message: Ol
# Messages Match: Matched
#
# [751/772] Processing image_00751.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00751.png
# Encoded Message: Zp
# Decoded Message: Zp
# Messages Match: Matched
#
# [752/772] Processing image_00752.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00752.png
# Encoded Message: qP
# Decoded Message: qP
# Messages Match: Matched
#
# [753/772] Processing image_00753.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00753.png
# Encoded Message: U5
# Decoded Message: U5
# Messages Match: Matched
#
# [754/772] Processing image_00754.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00754.png
# Encoded Message: 6m
# Decoded Message: 6m
# Messages Match: Matched
#
# [755/772] Processing image_00755.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00755.png
# Encoded Message: 6o
# Decoded Message: 6o
# Messages Match: Matched
#
# [756/772] Processing image_00756.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00756.png
# Encoded Message: yQ
# Decoded Message: yQ
# Messages Match: Matched
#
# [757/772] Processing image_00757.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00757.png
# Encoded Message: cp
# Decoded Message: cp
# Messages Match: Matched
#
# [758/772] Processing image_00758.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00758.png
# Encoded Message: WX
# Decoded Message: WX
# Messages Match: Matched
#
# [759/772] Processing image_00759.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00759.png
# Encoded Message: 2o
# Decoded Message: 2o
# Messages Match: Matched
#
# [760/772] Processing image_00760.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00760.png
# Encoded Message: P4
# Decoded Message: P4
# Messages Match: Matched
#
# [761/772] Processing image_00761.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00761.png
# Encoded Message: 4T
# Decoded Message: 4T
# Messages Match: Matched
#
# [762/772] Processing image_00762.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00762.png
# Encoded Message: z6
# Decoded Message: z6
# Messages Match: Matched
#
# [763/772] Processing image_00763.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00763.png
# Encoded Message: jb
# Decoded Message: jb
# Messages Match: Matched
#
# [764/772] Processing image_00764.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00764.png
# Encoded Message: px
# Decoded Message: px
# Messages Match: Matched
#
# [765/772] Processing image_00765.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00765.png
# Encoded Message: KK
# Decoded Message: KK
# Messages Match: Matched
#
# [766/772] Processing image_00766.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00766.png
# Encoded Message: GD
# Decoded Message: GD
# Messages Match: Matched
#
# [767/772] Processing image_00767.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00767.png
# Encoded Message: xD
# Decoded Message: xD
# Messages Match: Matched
#
# [768/772] Processing image_00768.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00768.png
# Encoded Message: gv
# Decoded Message: gv
# Messages Match: Matched
#
# [769/772] Processing image_00769.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00769.png
# Encoded Message: I7
# Decoded Message: I7
# Messages Match: Matched
#
# [770/772] Processing image_00770.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00770.png
# Encoded Message: T7
# Decoded Message: T7
# Messages Match: Matched
#
# [771/772] Processing image_00771.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00771.png
# Encoded Message: bx
# Decoded Message: bx
# Messages Match: Matched
#
# [772/772] Processing image_00772.png
# Stego image saved to Layered IG LSB/CNN MMS/Final Results (Normal)/stego_images\stego_image_00772.png
# Encoded Message: jH
# Decoded Message: jH
# Messages Match: Matched
#
#
# ✅ Done! Results saved to C:\Users\SIL-Laptop\Desktop\Final IAI Gustavo\steganography\Layered IG LSB\CNN MMS\ig_layered_stego_results.xlsx
#
# 📊 AVERAGE METRICS ACROSS ALL IMAGES:
# Average MSE: 586.4266967773438
# Average PSNR (dB): 20.4814
# Average SSIM: 0.9407
# Average Mean DCT Diff: 17.7151
# Average Max DCT Diff: 205.0933
# Message Match Rate (%): 100.0000
# Coordinate Match Rate (%): 100.0000
# CNN Accuracy After Embedding (%): 96.8912
